# %% [markdown]
# - Threshold policy: As we change threshold, look at p
# - w-Lookahead policy: As we change w, look at p
#
# We make some key changes to see if we can match Spencer et al. results.
#
# - we generate all arrivals ahead of time to compare their queue lengths over time
# - we set the fast service rate to 0 (jobs get deleted)
# - instead of looking at the proportion of time that we are in surge, we look at the proportion of jobs that get kicked out
# - Spencer et al. uses p to denote 1-slow service rate so we use alpha instead of p for the proportion of jobs that get kicked out

# %%
# %matplotlib inline
from pylab import *
import sys
from collections import namedtuple
import random
import time
import numpy as np

# %%
def log_normal(mu=0, sigma=1):
    return e**(mu+sigma*np.random.normal())

def exp_samples(lambd=1,n=1):
    """
    generates a numpy array of n samples distributed according to
    an exponential distribution with parameter λ
    """
    random.seed(time.time())
    return (-1/lambd)*log(rand(n))

def exp(lambd=1):
    """
    generates a sample distributed according to
    an exponential distribution with parameter λ
    """
    if lambd < 0:
        return inf()
    random.seed(time.time())
    return (-1/lambd)*log(rand())

def inf():
    return 999999


def printarray(a): 
    print(np.around(a, 3))
    

# Define customer for the threshold policy
Customer = namedtuple("Customer", "arrival_time")
def customer(arrival_time=-1):
    return Customer(arrival_time=arrival_time)

# Define customer for the w-lookahead policy
# mu1 is the slow service rate and mu2 is the fast service rate
WCustomer = namedtuple("WCustomer", "arrival_time slow_service_time fast_service_time enter_service_time service_time arrival_index fast")
def wcustomer(arrival_time=-1, mu1=-1, mu2=-1, arrival_index=0):
    slow = exp(mu1)
    fast = 0 #slow * mu1/mu2
    return WCustomer(arrival_time=arrival_time, slow_service_time=slow,
                     fast_service_time=fast, enter_service_time=-1,
                     service_time=-1, arrival_index=arrival_index, fast=False)

def wcustomer_with_parameters(w, current_time, fast):
    if fast:
        return WCustomer(arrival_time=w.arrival_time, slow_service_time=w.slow_service_time,
                         fast_service_time=w.fast_service_time, enter_service_time=current_time,
                         service_time=current_time+w.fast_service_time,
                         arrival_index=w.arrival_index, fast=True)
    return WCustomer(arrival_time=w.arrival_time, slow_service_time=w.slow_service_time,
                     fast_service_time=w.fast_service_time, enter_service_time=current_time,
                     service_time=current_time+w.slow_service_time,
                     arrival_index=w.arrival_index, fast=False)

def wcustomer_deleted(w):
    return WCustomer(arrival_time=w.arrival_time, slow_service_time=0,
                     fast_service_time=w.fast_service_time, enter_service_time=w.enter_service_time,
                     service_time=w.service_time,
                     arrival_index=w.arrival_index, fast=True)

# %%
lambd = 0.999
mu1 = 0.95
mu2 = 100 # doesn't matter in this case because fast gets kicked out immediately
c = 1
Tmax = 10000

surge_threshold = 80
w = 10000 # lookahead is online in this case

# %%
def gen_arrivals(lambd, mu1, mu2, Tmax): 
    # generate arrivals independent of whether or not we speed up the customers
    T_advance = [0]  # list of events that get generated in advance
    arrivals = []
    while T_advance[-1] < Tmax:
        t_temp = T_advance[-1]
        next_arrival = t_temp + exp(lambd)
        T_advance.append(next_arrival)
        arrivals.append(wcustomer(next_arrival, mu1, mu2, len(T_advance) - 2))
    return arrivals

# %%
arrivals = gen_arrivals(lambd, mu1, mu2, Tmax)

# %%
# Implement no policy (always use slow service time) on an array of arrivals.
# Returns T, N, waiting times. Proportion of surge is always 0.
def MM1Normal(arrivals, c, Tmax):
    T             = [0]  # list of times that events occur in real time
    N             = [0]  # initial state of the system
    
    # customers currently being served by a server
    servers = []
    
    # customers that are waiting to be served by a server
    queue = []
    
    # times spent by users inside the system
    waiting_times = []
    
    # arrival index represents when we either add to queue or to server if it's free
    arrival_index = 0
    arrivals_len = len(arrivals) - 1
    
    # first event must be an arrival
    next_arrival = arrivals[arrival_index].arrival_time
    next_departure = inf()
    
    while T[-1] < Tmax:
        T.append(min(next_arrival, next_departure))
        
        ##### ARRIVAL ##### 
        if T[-1] == next_arrival:
            N.append(N[-1] + 1) 
            arrival = arrivals[arrival_index]
            arrival_index += 1
            if len(servers) < c:
                servers.append(wcustomer_with_parameters(arrival, T[-1], False))
            else:
                queue.append(arrival)
                
        ##### DEPARTURE #####     
        elif T[-1] == next_departure:
            N.append(N[-1] - 1)
            popped_customer = servers.pop(0)
            T_in = popped_customer.arrival_time
            if T_in>0:
                waiting_times.append(T[-1] - T_in)
            # put the next person from the queue into the server
            if len(queue) > 0:
                next_to_enter = queue.pop(0)
                servers.append(wcustomer_with_parameters(next_to_enter, T[-1], False))
        
        if arrival_index < len(arrivals):
            next_arrival = arrivals[arrival_index].arrival_time
        else:
            next_arrival = inf()
        
        if len(servers) > 0:
            next_departure = servers[0].service_time
        else:
            next_departure = inf()
        
    # discard Tmax
    T = T[:-1] 
    N = N[:-1]
    return T, N, waiting_times

# %%
# Implement the threshold policy on an array of arrivals.
# Returns T, N, waiting times, proportion of surge
def MM1WithOneThreshold(arrivals, surge_threshold, c, Tmax):
    T               = [0]  # list of times that events occur
    N               = [0]  # initial state of the system
    use_surge_num   = 0
    use_surge_denom = 0
    
    # customers currently being served by a server
    servers = []
    
    # customers that are waiting to be served by a server
    queue = []
    
    # times spent by users inside the system
    waiting_times = []
    
    # arrival index represents when we either add to queue or to server if it's free
    arrival_index = 0
    arrivals_len = len(arrivals) - 1
    
    # first event must be an arrival
    next_arrival = arrivals[arrival_index].arrival_time
    next_departure = inf()
    
    while T[-1] < Tmax:
        T.append(min(next_arrival, next_departure))
        
        ##### ARRIVAL ##### 
        if next_arrival < next_departure:
            N.append(N[-1] + 1) 
            arrival = arrivals[arrival_index]
            arrival_index += 1
            if len(servers) < c:
                if N[-1] >= surge_threshold:
                    servers.append(wcustomer_with_parameters(arrival, T[-1], True))
                    if T[-1] > 1000:
                        use_surge_num += 1
                else:
                    servers.append(wcustomer_with_parameters(arrival, T[-1], False)) 
                if T[-1] > 1000:
                    use_surge_denom += 1
            else:
                queue.append(arrival)
            
        ##### DEPARTURE #####     
        else:
            N.append(N[-1] - 1)
            popped_customer = servers.pop(0)
            T_in = popped_customer.arrival_time
            if T_in>0:
                waiting_times.append(T[-1] - T_in)            
            if len(queue) > 0:
                next_to_enter = queue.pop(0)
                if N[-1] >= surge_threshold:
                    servers.append(wcustomer_with_parameters(next_to_enter, T[-1], True))
                    if T[-1] > 1000:
                        use_surge_num += 1
                else:
                    servers.append(wcustomer_with_parameters(next_to_enter, T[-1], False)) 
                if T[-1] > 1000:
                    use_surge_denom += 1
        
        if arrival_index < len(arrivals):
            next_arrival = arrivals[arrival_index].arrival_time
        else:
            next_arrival = inf()
        
        if len(servers) > 0:
            next_departure = servers[0].service_time
        else:
            next_departure = inf()
        
    # discard Tmax
    T = T[:-1] 
    N = N[:-1]
    return T, N, waiting_times, use_surge_num / use_surge_denom

# %%
# Implement the w-lookahead policy on an array of arrivals.
# Returns T, N, waiting times, proportion of surge
def MM1WithWLookaheadConstant(arrivals, c, w, Tmax):
    T               = [0]  # list of times that events occur in real time
    N               = [0]  # initial state of the system
    use_surge_num   = 0
    use_surge_denom = 0
    
    # customers currently being served by a server
    servers = []
    
    # customers that are waiting to be served by a server
    queue = []
    
    # times spent by users inside the system
    waiting_times = []
    
    # arrival index represents when we either add to queue or to server if it's free
    arrival_index = 0
    arrivals_len = len(arrivals) - 1
    
    
    # first event must be an arrival
    next_arrival = arrivals[arrival_index].arrival_time
    next_departure = inf()
    
    while T[-1] < Tmax:
        T.append(min(next_arrival, next_departure))
        
        ##### ARRIVAL ##### 
        if T[-1] == next_arrival:
            N.append(N[-1]+1) 
            arrival = arrivals[arrival_index]
            arrival_index += 1
            if len(servers) < c:
                # w-lookahead: decide whether to use fast or slow service rate
                cumulative_service_time = T[-1]
                w_lookahead = T[-1] + w
                num_arrivals = 0
                num_departures = 0
                arrival_lookahead_index = arrival_index
                service_lookahead_index = arrival.arrival_index
                use_slow = False
                while arrival_lookahead_index < arrivals_len and service_lookahead_index < arrivals_len:
                    w_arrival = arrivals[arrival_lookahead_index].arrival_time
                    w_departure = cumulative_service_time + arrivals[service_lookahead_index].slow_service_time
                    #print("arrival lookahead index %d, next arrival %.2f" % (arrival_lookahead_index, w_arrival))
                    #print("next departure %.2f" % (w_departure))
                    if w_arrival <= w_departure and w_arrival <= min(w_lookahead, Tmax):
                        num_arrivals += 1
                        arrival_lookahead_index += 1
                    elif w_departure <= min(w_lookahead, Tmax):
                        cumulative_service_time = w_departure
                        num_departures += 1      
                        service_lookahead_index += 1
                    else:
                        break
                        
                    if num_departures >= num_arrivals \
                        and num_departures > 0: # use the slow service rate 
                        use_slow = True
                        break
                        
                if use_slow:
                    servers.append(wcustomer_with_parameters(arrival, T[-1], False))
                    print("Look ahead from %d at time %.3f has Departures %d Arrivals %d -> use SLOW 1" % (N[-1], T[-1], num_departures, num_arrivals))
                else: # use the fast service rate
                    servers.append(wcustomer_with_parameters(arrival, T[-1], True))
                    #arrivals[arrival.arrival_index] = wcustomer_deleted(arrivals[arrival.arrival_index])
                    if T[-1] > 1000:
                        use_surge_num += 1
                    print("Look ahead from %d at time %.3f has Departures %d Arrivals %d -> use FAST 1" % (N[-1], T[-1], num_departures, num_arrivals))
                if T[-1] > 1000:
                    use_surge_denom += 1
            else:
                queue.append(arrival)
            #print("ARRIVAL %.3f departure %.3f abandonment %.3f" % (next_arrival, next_departure, next_abandonment))
        ##### DEPARTURE #####     
        else:
            N.append(N[-1]-1)
            popped_customer = servers.pop(0)
            T_in = popped_customer.arrival_time
            if T_in>0:
                waiting_times.append(T[-1] - T_in)
                
            # put the next person from the queue into the server
            if len(queue) > 0:
                next_to_enter = queue.pop(0)
                # w-lookahead: decide whether to use fast or slow service rate
                cumulative_service_time = T[-1]
                w_lookahead = T[-1] + w
                num_arrivals = 0
                num_departures = 0
                arrival_lookahead_index = arrival_index
                service_lookahead_index = next_to_enter.arrival_index
                use_slow = False
                while arrival_lookahead_index < arrivals_len and service_lookahead_index < arrivals_len:
                    w_arrival = arrivals[arrival_lookahead_index].arrival_time
                    w_departure = cumulative_service_time + arrivals[service_lookahead_index].slow_service_time
                    #print("arrival lookahead index %d, next arrival %.2f" % (arrival_lookahead_index, w_arrival))
                    #print("next departure %.2f" % (w_departure))
                        
                    if w_arrival <= w_departure and w_arrival <= min(w_lookahead, Tmax):
                        num_arrivals += 1
                        arrival_lookahead_index += 1
                        w_arrival = arrivals[arrival_lookahead_index].arrival_time
                    elif w_departure <= min(w_lookahead, Tmax):
                        cumulative_service_time = w_departure
                        num_departures += 1      
                        service_lookahead_index += 1
                    else:
                        break
                        
                    if num_departures >= num_arrivals \
                        and num_departures > 0: # use the slow service rate 
                        use_slow = True
                        break
                        
                if use_slow:
                    servers.append(wcustomer_with_parameters(next_to_enter, T[-1], False))
                    print("Look ahead from %d at time %.3f has Departures %d Arrivals %d -> use SLOW 2" % (N[-1], T[-1], num_departures, num_arrivals))
                else: # use the fast service rate
                    servers.append(wcustomer_with_parameters(next_to_enter, T[-1], True))
                    #arrivals[next_to_enter.arrival_index] = wcustomer_deleted(arrivals[next_to_enter.arrival_index])
                    if T[-1] > 1000:
                        use_surge_num += 1
                    print("Look ahead from %d at time %.3f has Departures %d Arrivals %d -> use FAST 2" % (N[-1], T[-1], num_departures, num_arrivals))
                if T[-1] > 1000:
                    use_surge_denom += 1
        
        if arrival_index < arrivals_len:
            next_arrival = arrivals[arrival_index].arrival_time
        else:
            next_arrival = inf()
        
        if len(servers) > 0:
            next_departure = servers[0].service_time
        else:
            next_departure = inf()
        
    # discard Tmax
    T = T[:-1] 
    N = N[:-1]
    return T, N, waiting_times, use_surge_num / use_surge_denom

# %% [markdown]
# # Graphs and Results

# %%
# Start and end proportions for graphing
start_prop = 0 #0.055
end_prop = 0.6 #0.058

# %%
#arrivals = gen_arrivals(lambd, mu1, mu2, Tmax)

# %%
T1, N1, _ = MM1Normal(arrivals, c, Tmax)
start_index1 = int(len(T1)*start_prop)
end_index1 = int(len(T1)*end_prop)
figure(figsize=(15,6))
plot(T1[start_index1:end_index1], N1[start_index1:end_index1])
#scatter(T1[start_index:end_index], N1[start_index:end_index])
xlabel('Time')
ylabel('Number of clients')
title('Number of clients in the M/M/C queue %.2f/%.2f/%d, with no policy' % (lambd, mu1, c))
# Out:
# Text(0.5,1,'Number of clients in the M/M/C queue 1.00/0.95/1, with no policy')

# %%
T3, N3, _, use_surge = MM1WithWLookaheadConstant(arrivals, c, w, Tmax)

start_index3 = int(len(T3)*start_prop)
end_index3 = int(len(T3)*end_prop)
figure(figsize=(15,6))
#scatter(T3[start_index:end_index], N3[start_index:end_index])
plot(T3[start_index3:end_index3], N3[start_index3:end_index3])
xlabel('Time')
ylabel('Number of clients')
title('Number of clients in the M/M/C queue %.2f/%.2f/%d, with w-lookahead online'
      % (lambd, mu1, c))
print("Use surge %.2f" % (use_surge))
# Out:
# Look ahead from 1 at time 0.100 has Departures 2 Arrivals 2 -> use SLOW 1
# Look ahead from 2 at time 1.818 has Departures 1 Arrivals 0 -> use SLOW 2
# Look ahead from 1 at time 1.843 has Departures 1 Arrivals 0 -> use SLOW 2
# Look ahead from 1 at time 2.741 has Departures 9349 Arrivals 10059 -> use FAST 1
# Look ahead from 1 at time 2.816 has Departures 1 Arrivals 0 -> use SLOW 1
# Look ahead from 1 at time 4.693 has Departures 1 Arrivals 0 -> use SLOW 1
# Look ahead from 1 at time 5.211 has Departures 1 Arrivals 1 -> use SLOW 1
# Look ahead from 1 at time 6.198 has Departures 1 Arrivals 0 -> use SLOW 2
# Look ahead from 1 at time 6.642 has Departures 9347 Arrivals 10054 -> use FAST 1
# Look ahead from 1 at time 6.746 has Departures 1 Arrivals 0 -> use SLOW 1
# Look ahead from 1 at time 7.174 has Departures 5 Arrivals 5 -> use SLOW 1
# Look ahead from 3 at time 8.904 has Departures 1 Arrivals 0 -> use SLOW 2
# Look ahead from 2 at time 9.471 has Departures 2 Arrivals 2 -> use SLOW 2
# Look ahead from 3 at time 11.147 has Departures 1 Arrivals 0 -> use SLOW 2
# Look ahead from 2 at time 11.968 has Departures 1 Arrivals 0 -> use SLOW 2
# Look ahead from 1 at time 12.071 has Departures 1 Arrivals 0 -> use SLOW 2
# Look ahead from 1 at time 13.710 has Departures 1 Arrivals 1 -> use SLOW 1
# Look ahead from 1 at time 15.259 has Departures 9339 Arrivals 10045 -> use FAST 2
# Look ahead from 1 at time 16.168 has Departures 4 Arrivals 4 -> use SLOW 1
# Look ahead from 4 at time 17.687 has Departures 1 Arrivals 0 -> use SLOW 2
# Look ahead from 3 at time 17.886 has Departures 1 Arrivals 0 -> use SLOW 2
# Look ahead from 2 at time 17.965 has Departures 1 Arrivals 0 -> use SLOW 2
# Look ahead from 1 at time 18.438 has Departures 2 Arrivals 2 -> use SLOW 2
# Look ahead from 2 at time 21.702 has Departures 1 Arrivals 0 -> use SLOW 2
# Look ahead from 1 at time 21.956 has Departures 1 Arrivals 1 -> use SLOW 2
# Look ahead from 1 at time 23.050 has Departures 9332 Arrivals 10037 -> use FAST 2
# Look ahead from 1 at time 23.408 has Departures 9331 Arrivals 10036 -> use FAST 1
# Look ahead from 1 at time 24.248 has Departures 9331 Arrivals 10035 -> use FAST 1
# Look ahead from 1 at time 24.581 has Departures 1 Arrivals 0 -> use SLOW 1
# Look ahead from 1 at time 24.856 has Departures 9332 Arrivals 10033 -> use FAST 1
# Look ahead from 1 at time 24.869 has Departures 1 Arrivals 0 -> use SLOW 1
# Look ahead from 1 at time 25.157 has Departures 9335 Arrivals 10031 -> use FAST 1
# Look ahead from 1 at time 26.112 has Departures 2 Arrivals 2 -> use SLOW 1
# Look ahead from 2 at time 28.287 has Departures 1 Arrivals 0 -> use SLOW 2
# Look ahead from 1 at time 28.455 has Departures 2 Arrivals 2 -> use SLOW 2
# Look ahead from 2 at time 29.815 has Departures 1 Arrivals 0 -> use SLOW 2
# Look ahead from 1 at time 29.894 has Departures 1 Arrivals 1 -> use SLOW 2
# Look ahead from 1 at time 30.392 has Departures 9330 Arrivals 10025 -> use FAST 2
# Look ahead from 1 at time 31.125 has Departures 1 Arrivals 1 -> use SLOW 1
# Look ahead from 1 at time 32.252 has Departures 1 Arrivals 1 -> use SLOW 2
# Look ahead from 1 at time 32.388 has Departures 1 Arrivals 1 -> use SLOW 2
# Look ahead from 1 at time 33.527 has Departures 9327 Arrivals 10021 -> use FAST 2
# Look ahead from 1 at time 34.012 has Departures 1 Arrivals 0 -> use SLOW 1
# Look ahead from 1 at time 35.502 has Departures 1 Arrivals 1 -> use SLOW 1
# Look ahead from 1 at time 36.864 has Departures 1 Arrivals 1 -> use SLOW 2
# Look ahead from 1 at time 39.001 has Departures 1 Arrivals 0 -> use SLOW 2
# Look ahead from 1 at time 39.312 has Departures 1 Arrivals 1 -> use SLOW 1
# Look ahead from 1 at time 39.938 has Departures 1 Arrivals 1 -> use SLOW 2
# Look ahead from 1 at time 41.103 has Departures 1 Arrivals 0 -> use SLOW 2
# Look ahead from 1 at time 41.714 has Departures 1 Arrivals 1 -> use SLOW 1
# Look ahead from 1 at time 44.130 has Departures 1 Arrivals 1 -> use SLOW 2
# Look ahead from 1 at time 44.879 has Departures 1 Arrivals 0 -> use SLOW 2
# Look ahead from 1 at time 45.093 has Departures 3 Arrivals 3 -> use SLOW 1
# Look ahead from 2 at time 45.829 has Departures 1 Arrivals 1 -> use SLOW 2
# Look ahead from 2 at time 47.544 has Departures 1 Arrivals 0 -> use SLOW 2
# Look ahead from 1 at time 47.821 has Departures 1 Arrivals 1 -> use SLOW 2
# Look ahead from 1 at time 49.063 has Departures 1 Arrivals 1 -> use SLOW 2
# Look ahead from 1 at time 50.706 has Departures 9311 Arrivals 10005 -> use FAST 2
# Look ahead from 1 at time 51.493 has Departures 9311 Arrivals 10004 -> use FAST 1
# Look ahead from 1 at time 52.229 has Departures 9310 Arrivals 10003 -> use FAST 1
# Look ahead from 1 at time 52.375 has Departures 1 Arrivals 0 -> use SLOW 1
# Look ahead from 1 at time 53.195 has Departures 9308 Arrivals 10001 -> use FAST 1
# Look ahead from 1 at time 53.205 has Departures 7 Arrivals 7 -> use SLOW 1
# Look ahead from 3 at time 55.058 has Departures 1 Arrivals 1 -> use SLOW 2
# Look ahead from 3 at time 55.312 has Departures 1 Arrivals 0 -> use SLOW 2
# Look ahead from 2 at time 56.092 has Departures 2 Arrivals 2 -> use SLOW 2
# Look ahead from 3 at time 56.503 has Departures 1 Arrivals 0 -> use SLOW 2
# Look ahead from 2 at time 57.123 has Departures 1 Arrivals 1 -> use SLOW 2
# Look ahead from 2 at time 59.743 has Departures 1 Arrivals 0 -> use SLOW 2
# Look ahead from 1 at time 60.796 has Departures 9302 Arrivals 9993 -> use FAST 2
# Look ahead from 1 at time 61.497 has Departures 1 Arrivals 1 -> use SLOW 1
# Look ahead from 1 at time 63.092 has Departures 1 Arrivals 0 -> use SLOW 2
# Look ahead from 1 at time 63.261 has Departures 2 Arrivals 2 -> use SLOW 1
# Look ahead from 2 at time 67.502 has Departures 1 Arrivals 0 -> use SLOW 2
# Look ahead from 1 at time 67.575 has Departures 1 Arrivals 1 -> use SLOW 2
# Look ahead from 1 at time 68.873 has Departures 1 Arrivals 0 -> use SLOW 2
# Look ahead from 1 at time 69.377 has Departures 9296 Arrivals 9986 -> use FAST 1
# Look ahead from 1 at time 69.835 has Departures 9296 Arrivals 9985 -> use FAST 1
# Look ahead from 1 at time 69.897 has Departures 25 Arrivals 25 -> use SLOW 1
# Look ahead from 2 at time 70.851 has Departures 23 Arrivals 23 -> use SLOW 2
# Look ahead from 4 at time 72.008 has Departures 1 Arrivals 1 -> use SLOW 2
# Look ahead from 4 at time 72.562 has Departures 2 Arrivals 2 -> use SLOW 2
# Look ahead from 5 at time 73.573 has Departures 1 Arrivals 0 -> use SLOW 2
# Look ahead from 4 at time 73.934 has Departures 3 Arrivals 3 -> use SLOW 2
# Look ahead from 5 at time 75.989 has Departures 1 Arrivals 1 -> use SLOW 2
# Look ahead from 5 at time 77.774 has Departures 1 Arrivals 0 -> use SLOW 2
# Look ahead from 4 at time 78.313 has Departures 1 Arrivals 1 -> use SLOW 2
# Look ahead from 4 at time 78.773 has Departures 1 Arrivals 1 -> use SLOW 2
# Look ahead from 4 at time 81.296 has Departures 10 Arrivals 10 -> use SLOW 2
# Look ahead from 7 at time 84.561 has Departures 1 Arrivals 0 -> use SLOW 2
# Look ahead from 6 at time 84.961 has Departures 1 Arrivals 0 -> use SLOW 2
# Look ahead from 5 at time 85.458 has Departures 5 Arrivals 5 -> use SLOW 2
# Look ahead from 9 at time 88.017 has Departures 1 Arrivals 0 -> use SLOW 2
# Look ahead from 8 at time 88.066 has Departures 1 Arrivals 0 -> use SLOW 2
# Look ahead from 7 at time 88.081 has Departures 1 Arrivals 0 -> use SLOW 2
# Look ahead from 6 at time 88.889 has Departures 1 Arrivals 0 -> use SLOW 2
# Look ahead from 5 at time 88.975 has Departures 1 Arrivals 1 -> use SLOW 2
# Look ahead from 5 at time 89.478 has Departures 1 Arrivals 0 -> use SLOW 2
# Look ahead from 4 at time 89.751 has Departures 1 Arrivals 0 -> use SLOW 2
# Look ahead from 3 at time 90.298 has Departures 1 Arrivals 1 -> use SLOW 2
# Look ahead from 3 at time 91.217 has Departures 1 Arrivals 1 -> use SLOW 2
# Look ahead from 3 at time 92.153 has Departures 1 Arrivals 0 -> use SLOW 2
# Look ahead from 2 at time 93.089 has Departures 1 Arrivals 0 -> use SLOW 2
# Look ahead from 1 at time 93.583 has Departures 1 Arrivals 1 -> use SLOW 2
# Look ahead from 1 at time 94.398 has Departures 9270 Arrivals 9958 -> use FAST 2
# Look ahead from 1 at time 94.492 has Departures 10 Arrivals 10 -> use SLOW 1
# Look ahead from 3 at time 97.048 has Departures 3 Arrivals 3 -> use SLOW 2
# Look ahead from 5 at time 98.361 has Departures 1 Arrivals 0 -> use SLOW 2
# Look ahead from 4 at time 98.562 has Departures 1 Arrivals 0 -> use SLOW 2
# Look ahead from 3 at time 98.796 has Departures 4 Arrivals 4 -> use SLOW 2
# Look ahead from 6 at time 102.120 has Departures 1 Arrivals 0 -> use SLOW 2
# Look ahead from 5 at time 102.120 has Departures 1 Arrivals 0 -> use SLOW 2
# Look ahead from 4 at time 103.031 has Departures 1 Arrivals 0 -> use SLOW 2
# Look ahead from 3 at time 105.461 has Departures 1 Arrivals 0 -> use SLOW 2
# Look ahead from 2 at time 105.809 has Departures 1 Arrivals 0 -> use SLOW 2
# Look ahead from 1 at time 106.031 has Departures 9262 Arrivals 9947 -> use FAST 2
# Look ahead from 1 at time 106.087 has Departures 1 Arrivals 0 -> use SLOW 1
# Look ahead from 1 at time 106.551 has Departures 9268 Arrivals 9945 -> use FAST 1
# Look ahead from 1 at time 106.745 has Departures 1 Arrivals 1 -> use SLOW 1
# Look ahead from 1 at time 107.737 has Departures 1 Arrivals 1 -> use SLOW 2
# Look ahead from 1 at time 108.412 has Departures 1 Arrivals 0 -> use SLOW 2
# Look ahead from 1 at time 108.958 has Departures 1 Arrivals 0 -> use SLOW 1
# Look ahead from 1 at time 110.739 has Departures 1 Arrivals 1 -> use SLOW 1
# Look ahead from 1 at time 111.408 has Departures 9263 Arrivals 9939 -> use FAST 2
# Look ahead from 1 at time 111.930 has Departures 9262 Arrivals 9938 -> use FAST 1
# Look ahead from 1 at time 112.134 has Departures 9261 Arrivals 9937 -> use FAST 1
# Look ahead from 1 at time 112.199 has Departures 9261 Arrivals 9936 -> use FAST 1
# Look ahead from 1 at time 112.325 has Departures 27 Arrivals 27 -> use SLOW 1
# Look ahead from 2 at time 113.334 has Departures 20 Arrivals 20 -> use SLOW 2
# Look ahead from 11 at time 118.416 has Departures 1 Arrivals 1 -> use SLOW 2
# Look ahead from 11 at time 118.941 has Departures 1 Arrivals 0 -> use SLOW 2
# Look ahead from 10 at time 119.471 has Departures 1 Arrivals 0 -> use SLOW 2
# Look ahead from 9 at time 119.800 has Departures 1 Arrivals 0 -> use SLOW 2
# Look ahead from 8 at time 119.841 has Departures 1 Arrivals 1 -> use SLOW 2
# Look ahead from 8 at time 120.238 has Departures 1 Arrivals 1 -> use SLOW 2
# Look ahead from 8 at time 121.117 has Departures 1 Arrivals 0 -> use SLOW 2
# Look ahead from 7 at time 121.497 has Departures 1 Arrivals 0 -> use SLOW 2
# Look ahead from 6 at time 121.667 has Departures 1 Arrivals 1 -> use SLOW 2
# Look ahead from 6 at time 122.641 has Departures 1 Arrivals 0 -> use SLOW 2
# Look ahead from 5 at time 122.743 has Departures 1 Arrivals 1 -> use SLOW 2
# Look ahead from 5 at time 124.061 has Departures 3 Arrivals 3 -> use SLOW 2
# Look ahead from 7 at time 126.786 has Departures 1 Arrivals 0 -> use SLOW 2
# Look ahead from 6 at time 127.754 has Departures 1 Arrivals 0 -> use SLOW 2
# Look ahead from 5 at time 127.987 has Departures 2 Arrivals 2 -> use SLOW 2
# Look ahead from 6 at time 130.333 has Departures 1 Arrivals 0 -> use SLOW 2
# Look ahead from 5 at time 130.420 has Departures 1 Arrivals 0 -> use SLOW 2
# Look ahead from 4 at time 130.982 has Departures 1 Arrivals 0 -> use SLOW 2
# Look ahead from 3 at time 131.407 has Departures 1 Arrivals 0 -> use SLOW 2
# Look ahead from 2 at time 132.040 has Departures 5 Arrivals 5 -> use SLOW 2
# Look ahead from 4 at time 135.106 has Departures 1 Arrivals 1 -> use SLOW 2
# Look ahead from 4 at time 135.504 has Departures 1 Arrivals 1 -> use SLOW 2
# Look ahead from 4 at time 136.446 has Departures 1 Arrivals 0 -> use SLOW 2
# Look ahead from 3 at time 138.527 has Departures 1 Arrivals 0 -> use SLOW 2
# Look ahead from 2 at time 140.147 has Departures 1 Arrivals 0 -> use SLOW 2
# Look ahead from 1 at time 140.704 has Departures 1 Arrivals 1 -> use SLOW 2
# Look ahead from 1 at time 142.481 has Departures 1 Arrivals 0 -> use SLOW 2
# Look ahead from 1 at time 143.461 has Departures 9231 Arrivals 9906 -> use FAST 1
# Look ahead from 1 at time 144.136 has Departures 9238 Arrivals 9905 -> use FAST 1
# Look ahead from 1 at time 144.262 has Departures 29 Arrivals 29 -> use SLOW 1
# Look ahead from 4 at time 147.199 has Departures 12 Arrivals 12 -> use SLOW 2
# Look ahead from 7 at time 148.143 has Departures 1 Arrivals 0 -> use SLOW 2
# Look ahead from 6 at time 148.339 has Departures 6 Arrivals 6 -> use SLOW 2
# Look ahead from 7 at time 148.872 has Departures 4 Arrivals 4 -> use SLOW 2
# Look ahead from 8 at time 149.804 has Departures 2 Arrivals 2 -> use SLOW 2
# Look ahead from 9 at time 154.071 has Departures 1 Arrivals 0 -> use SLOW 2
# Look ahead from 8 at time 154.533 has Departures 1 Arrivals 0 -> use SLOW 2
# Look ahead from 7 at time 154.813 has Departures 1 Arrivals 0 -> use SLOW 2
# Look ahead from 6 at time 155.971 has Departures 1 Arrivals 1 -> use SLOW 2
# Look ahead from 6 at time 157.574 has Departures 1 Arrivals 1 -> use SLOW 2
# Look ahead from 6 at time 158.230 has Departures 1 Arrivals 0 -> use SLOW 2
# Look ahead from 5 at time 158.934 has Departures 1 Arrivals 0 -> use SLOW 2
# Look ahead from 4 at time 159.073 has Departures 3 Arrivals 3 -> use SLOW 2
# Look ahead from 6 at time 159.462 has Departures 1 Arrivals 0 -> use SLOW 2
# Look ahead from 5 at time 159.792 has Departures 1 Arrivals 0 -> use SLOW 2
# Look ahead from 4 at time 159.817 has Departures 1 Arrivals 1 -> use SLOW 2
# Look ahead from 4 at time 160.826 has Departures 1 Arrivals 0 -> use SLOW 2
# Look ahead from 3 at time 161.491 has Departures 1 Arrivals 1 -> use SLOW 2
# Look ahead from 3 at time 162.352 has Departures 1 Arrivals 1 -> use SLOW 2
# Look ahead from 3 at time 163.695 has Departures 5 Arrivals 5 -> use SLOW 2
# Look ahead from 6 at time 166.876 has Departures 1 Arrivals 0 -> use SLOW 2
# Look ahead from 5 at time 167.323 has Departures 1 Arrivals 0 -> use SLOW 2
# Look ahead from 4 at time 169.140 has Departures 1 Arrivals 1 -> use SLOW 2
# Look ahead from 4 at time 170.143 has Departures 1 Arrivals 0 -> use SLOW 2
# Look ahead from 3 at time 170.439 has Departures 1 Arrivals 0 -> use SLOW 2
# Look ahead from 2 at time 170.446 has Departures 1 Arrivals 1 -> use SLOW 2
# Look ahead from 2 at time 172.110 has Departures 1 Arrivals 1 -> use SLOW 2
# Look ahead from 2 at time 172.864 has Departures 1 Arrivals 0 -> use SLOW 2
# Look ahead from 1 at time 173.114 has Departures 9 Arrivals 9 -> use SLOW 2
# Look ahead from 2 at time 174.257 has Departures 2 Arrivals 2 -> use SLOW 2
# Look ahead from 3 at time 176.561 has Departures 1 Arrivals 0 -> use SLOW 2
# Look ahead from 2 at time 176.800 has Departures 3 Arrivals 3 -> use SLOW 2
# Look ahead from 4 at time 177.822 has Departures 1 Arrivals 0 -> use SLOW 2
# Look ahead from 3 at time 177.822 has Departures 1 Arrivals 0 -> use SLOW 2
# Look ahead from 2 at time 179.693 has Departures 1 Arrivals 1 -> use SLOW 2
# Look ahead from 2 at time 180.517 has Departures 1 Arrivals 1 -> use SLOW 2
# Look ahead from 2 at time 182.296 has Departures 1 Arrivals 0 -> use SLOW 2
# Look ahead from 1 at time 182.441 has Departures 9200 Arrivals 9866 -> use FAST 2
# Look ahead from 1 at time 183.371 has Departures 2 Arrivals 2 -> use SLOW 1
# Look ahead from 2 at time 185.934 has Departures 1 Arrivals 0 -> use SLOW 2
# Look ahead from 1 at time 186.951 has Departures 9199 Arrivals 9863 -> use FAST 2
# Look ahead from 1 at time 186.975 has Departures 1 Arrivals 0 -> use SLOW 1
# Look ahead from 1 at time 187.372 has Departures 1 Arrivals 1 -> use SLOW 1
# Look ahead from 1 at time 187.718 has Departures 1 Arrivals 0 -> use SLOW 2
# Look ahead from 1 at time 187.954 has Departures 4 Arrivals 4 -> use SLOW 1
# Look ahead from 3 at time 190.027 has Departures 1 Arrivals 0 -> use SLOW 2
# Look ahead from 2 at time 190.502 has Departures 1 Arrivals 1 -> use SLOW 2
# Look ahead from 2 at time 193.058 has Departures 1 Arrivals 0 -> use SLOW 2
# Look ahead from 1 at time 193.155 has Departures 1 Arrivals 1 -> use SLOW 2
# Look ahead from 1 at time 194.810 has Departures 4 Arrivals 4 -> use SLOW 2
# Look ahead from 3 at time 195.844 has Departures 1 Arrivals 1 -> use SLOW 2
# Look ahead from 3 at time 197.346 has Departures 1 Arrivals 0 -> use SLOW 2
# Look ahead from 2 at time 197.996 has Departures 1 Arrivals 0 -> use SLOW 2
# Look ahead from 1 at time 198.743 has Departures 1 Arrivals 0 -> use SLOW 2
# Look ahead from 1 at time 199.428 has Departures 1 Arrivals 0 -> use SLOW 1
# Look ahead from 1 at time 200.234 has Departures 32 Arrivals 32 -> use SLOW 1
# Look ahead from 2 at time 202.409 has Departures 30 Arrivals 30 -> use SLOW 2
# Look ahead from 4 at time 204.851 has Departures 3 Arrivals 3 -> use SLOW 2
# Look ahead from 5 at time 207.708 has Departures 1 Arrivals 1 -> use SLOW 2
# Look ahead from 5 at time 208.690 has Departures 1 Arrivals 0 -> use SLOW 2
# Look ahead from 4 at time 209.005 has Departures 1 Arrivals 0 -> use SLOW 2
# Look ahead from 3 at time 209.617 has Departures 3 Arrivals 3 -> use SLOW 2
# Look ahead from 4 at time 210.927 has Departures 1 Arrivals 1 -> use SLOW 2
# Look ahead from 4 at time 213.126 has Departures 1 Arrivals 0 -> use SLOW 2
# Look ahead from 3 at time 213.170 has Departures 20 Arrivals 20 -> use SLOW 2
# Look ahead from 9 at time 218.339 has Departures 1 Arrivals 0 -> use SLOW 2
# Look ahead from 8 at time 219.728 has Departures 1 Arrivals 0 -> use SLOW 2
# Look ahead from 7 at time 219.749 has Departures 1 Arrivals 1 -> use SLOW 2
# Look ahead from 7 at time 221.298 has Departures 1 Arrivals 1 -> use SLOW 2
# Look ahead from 7 at time 221.710 has Departures 5 Arrivals 5 -> use SLOW 2
# Look ahead from 10 at time 222.853 has Departures 1 Arrivals 1 -> use SLOW 2
# Look ahead from 10 at time 224.317 has Departures 1 Arrivals 0 -> use SLOW 2
# Look ahead from 9 at time 224.537 has Departures 1 Arrivals 0 -> use SLOW 2
# Look ahead from 8 at time 226.220 has Departures 1 Arrivals 0 -> use SLOW 2
# Look ahead from 7 at time 227.178 has Departures 1 Arrivals 0 -> use SLOW 2
# Look ahead from 6 at time 227.463 has Departures 1 Arrivals 0 -> use SLOW 2
# Look ahead from 5 at time 227.890 has Departures 1 Arrivals 0 -> use SLOW 2
# Look ahead from 4 at time 227.969 has Departures 1 Arrivals 1 -> use SLOW 2
# Look ahead from 4 at time 228.518 has Departures 4 Arrivals 4 -> use SLOW 2
# Look ahead from 6 at time 232.633 has Departures 1 Arrivals 0 -> use SLOW 2
# Look ahead from 5 at time 233.306 has Departures 1 Arrivals 1 -> use SLOW 2
# Look ahead from 5 at time 234.493 has Departures 1 Arrivals 0 -> use SLOW 2
# Look ahead from 4 at time 234.580 has Departures 1 Arrivals 1 -> use SLOW 2
# Look ahead from 4 at time 236.004 has Departures 1 Arrivals 0 -> use SLOW 2
# Look ahead from 3 at time 236.504 has Departures 1 Arrivals 1 -> use SLOW 2
# Look ahead from 3 at time 237.780 has Departures 1 Arrivals 0 -> use SLOW 2
# Look ahead from 2 at time 238.243 has Departures 1 Arrivals 0 -> use SLOW 2
# Look ahead from 1 at time 238.326 has Departures 9155 Arrivals 9816 -> use FAST 2
# Look ahead from 1 at time 238.396 has Departures 9156 Arrivals 9815 -> use FAST 1
# Look ahead from 1 at time 238.814 has Departures 4 Arrivals 4 -> use SLOW 1
# Look ahead from 2 at time 239.409 has Departures 2 Arrivals 2 -> use SLOW 2
# Look ahead from 3 at time 241.425 has Departures 1 Arrivals 0 -> use SLOW 2
# Look ahead from 2 at time 242.433 has Departures 1 Arrivals 0 -> use SLOW 2
# Look ahead from 1 at time 242.574 has Departures 1 Arrivals 1 -> use SLOW 2
# Look ahead from 1 at time 243.148 has Departures 2 Arrivals 2 -> use SLOW 2
# Look ahead from 2 at time 243.880 has Departures 1 Arrivals 0 -> use SLOW 2
# Look ahead from 1 at time 244.309 has Departures 9152 Arrivals 9807 -> use FAST 2
# Look ahead from 1 at time 244.331 has Departures 9153 Arrivals 9806 -> use FAST 1
# Look ahead from 1 at time 244.657 has Departures 1 Arrivals 0 -> use SLOW 1
# Look ahead from 1 at time 245.290 has Departures 6 Arrivals 6 -> use SLOW 1
# Look ahead from 3 at time 246.943 has Departures 2 Arrivals 2 -> use SLOW 2
# Look ahead from 4 at time 247.587 has Departures 1 Arrivals 0 -> use SLOW 2
# Look ahead from 3 at time 248.365 has Departures 1 Arrivals 1 -> use SLOW 2
# Look ahead from 3 at time 249.388 has Departures 1 Arrivals 0 -> use SLOW 2
# Look ahead from 2 at time 249.485 has Departures 1 Arrivals 0 -> use SLOW 2
# Look ahead from 1 at time 249.497 has Departures 1 Arrivals 0 -> use SLOW 2
# Look ahead from 1 at time 250.084 has Departures 9144 Arrivals 9797 -> use FAST 1
# Look ahead from 1 at time 250.383 has Departures 1 Arrivals 1 -> use SLOW 1
# Look ahead from 1 at time 250.801 has Departures 1 Arrivals 0 -> use SLOW 2
# Look ahead from 1 at time 251.342 has Departures 9144 Arrivals 9794 -> use FAST 1
# Look ahead from 1 at time 251.439 has Departures 9143 Arrivals 9793 -> use FAST 1
# Look ahead from 1 at time 251.731 has Departures 2 Arrivals 2 -> use SLOW 1
# Look ahead from 2 at time 255.773 has Departures 1 Arrivals 0 -> use SLOW 2
# Look ahead from 1 at time 255.841 has Departures 2 Arrivals 2 -> use SLOW 2
# Look ahead from 2 at time 256.479 has Departures 1 Arrivals 0 -> use SLOW 2
# Look ahead from 1 at time 256.819 has Departures 8 Arrivals 8 -> use SLOW 2
# Look ahead from 4 at time 259.165 has Departures 3 Arrivals 3 -> use SLOW 2
# Look ahead from 5 at time 259.713 has Departures 1 Arrivals 1 -> use SLOW 2
# Look ahead from 5 at time 262.781 has Departures 1 Arrivals 0 -> use SLOW 2
# Look ahead from 4 at time 263.398 has Departures 1 Arrivals 0 -> use SLOW 2
# Look ahead from 3 at time 264.952 has Departures 1 Arrivals 1 -> use SLOW 2
# Look ahead from 3 at time 266.092 has Departures 1 Arrivals 0 -> use SLOW 2
# Look ahead from 2 at time 266.156 has Departures 1 Arrivals 0 -> use SLOW 2
# Look ahead from 1 at time 267.023 has Departures 1 Arrivals 1 -> use SLOW 2
# Look ahead from 1 at time 267.162 has Departures 1 Arrivals 1 -> use SLOW 2
# Look ahead from 1 at time 267.242 has Departures 1 Arrivals 0 -> use SLOW 2
# Look ahead from 1 at time 268.020 has Departures 1 Arrivals 0 -> use SLOW 1
# Look ahead from 1 at time 268.282 has Departures 1 Arrivals 0 -> use SLOW 1
# Look ahead from 1 at time 268.374 has Departures 40 Arrivals 40 -> use SLOW 1
# Look ahead from 2 at time 269.509 has Departures 35 Arrivals 35 -> use SLOW 2
# Look ahead from 3 at time 270.244 has Departures 24 Arrivals 24 -> use SLOW 2
# Look ahead from 7 at time 273.912 has Departures 1 Arrivals 1 -> use SLOW 2
# Look ahead from 7 at time 274.346 has Departures 2 Arrivals 2 -> use SLOW 2
# Look ahead from 8 at time 275.186 has Departures 1 Arrivals 0 -> use SLOW 2
# Look ahead from 7 at time 275.400 has Departures 2 Arrivals 2 -> use SLOW 2
# Look ahead from 8 at time 276.431 has Departures 1 Arrivals 0 -> use SLOW 2
# Look ahead from 7 at time 276.716 has Departures 1 Arrivals 0 -> use SLOW 2
# Look ahead from 6 at time 277.039 has Departures 1 Arrivals 0 -> use SLOW 2
# Look ahead from 5 at time 277.100 has Departures 3 Arrivals 3 -> use SLOW 2
# Look ahead from 7 at time 280.122 has Departures 1 Arrivals 0 -> use SLOW 2
# Look ahead from 6 at time 280.530 has Departures 1 Arrivals 0 -> use SLOW 2
# Look ahead from 5 at time 280.649 has Departures 2 Arrivals 2 -> use SLOW 2
# Look ahead from 6 at time 282.202 has Departures 1 Arrivals 0 -> use SLOW 2
# Look ahead from 5 at time 283.559 has Departures 1 Arrivals 0 -> use SLOW 2
# Look ahead from 4 at time 284.576 has Departures 9 Arrivals 9 -> use SLOW 2
# Look ahead from 9 at time 287.233 has Departures 1 Arrivals 0 -> use SLOW 2
# Look ahead from 8 at time 287.557 has Departures 1 Arrivals 1 -> use SLOW 2
# Look ahead from 8 at time 288.467 has Departures 1 Arrivals 0 -> use SLOW 2
# Look ahead from 7 at time 289.433 has Departures 1 Arrivals 1 -> use SLOW 2
# Look ahead from 7 at time 290.121 has Departures 1 Arrivals 0 -> use SLOW 2
# Look ahead from 6 at time 290.663 has Departures 1 Arrivals 0 -> use SLOW 2
# Look ahead from 5 at time 291.195 has Departures 1 Arrivals 1 -> use SLOW 2
# Look ahead from 5 at time 292.288 has Departures 1 Arrivals 0 -> use SLOW 2
# Look ahead from 4 at time 292.783 has Departures 1 Arrivals 0 -> use SLOW 2
# Look ahead from 3 at time 292.977 has Departures 2 Arrivals 2 -> use SLOW 2
# Look ahead from 4 at time 293.803 has Departures 1 Arrivals 0 -> use SLOW 2
# Look ahead from 3 at time 293.918 has Departures 5 Arrivals 5 -> use SLOW 2
# Look ahead from 6 at time 295.759 has Departures 1 Arrivals 1 -> use SLOW 2
# Look ahead from 6 at time 296.221 has Departures 1 Arrivals 0 -> use SLOW 2
# Look ahead from 5 at time 298.015 has Departures 1 Arrivals 0 -> use SLOW 2
# Look ahead from 4 at time 298.480 has Departures 1 Arrivals 0 -> use SLOW 2
# Look ahead from 3 at time 298.637 has Departures 1 Arrivals 1 -> use SLOW 2
# Look ahead from 3 at time 298.891 has Departures 1 Arrivals 1 -> use SLOW 2
# Look ahead from 3 at time 299.932 has Departures 1 Arrivals 0 -> use SLOW 2
# Look ahead from 2 at time 300.615 has Departures 2 Arrivals 2 -> use SLOW 2
# Look ahead from 3 at time 301.187 has Departures 1 Arrivals 0 -> use SLOW 2
# Look ahead from 2 at time 301.576 has Departures 1 Arrivals 1 -> use SLOW 2
# Look ahead from 2 at time 301.857 has Departures 1 Arrivals 0 -> use SLOW 2
# Look ahead from 1 at time 301.902 has Departures 9085 Arrivals 9735 -> use FAST 2
# Look ahead from 1 at time 301.945 has Departures 9084 Arrivals 9734 -> use FAST 1
# Look ahead from 1 at time 302.553 has Departures 4 Arrivals 4 -> use SLOW 1
# Look ahead from 4 at time 305.535 has Departures 1 Arrivals 0 -> use SLOW 2
# Look ahead from 3 at time 305.779 has Departures 1 Arrivals 0 -> use SLOW 2
# Look ahead from 2 at time 306.734 has Departures 1 Arrivals 0 -> use SLOW 2
# Look ahead from 1 at time 306.946 has Departures 4 Arrivals 4 -> use SLOW 2
# Look ahead from 2 at time 307.931 has Departures 1 Arrivals 1 -> use SLOW 2
# Look ahead from 2 at time 308.513 has Departures 1 Arrivals 1 -> use SLOW 2
# Look ahead from 2 at time 309.740 has Departures 1 Arrivals 0 -> use SLOW 2
# Look ahead from 1 at time 310.382 has Departures 2 Arrivals 2 -> use SLOW 2
# Look ahead from 2 at time 311.904 has Departures 1 Arrivals 0 -> use SLOW 2
# Look ahead from 1 at time 311.929 has Departures 1 Arrivals 0 -> use SLOW 2
# Look ahead from 1 at time 314.267 has Departures 1 Arrivals 1 -> use SLOW 1
# Look ahead from 1 at time 315.061 has Departures 1 Arrivals 0 -> use SLOW 2
# Look ahead from 1 at time 316.008 has Departures 2 Arrivals 2 -> use SLOW 1
# Look ahead from 2 at time 319.058 has Departures 1 Arrivals 0 -> use SLOW 2
# Look ahead from 1 at time 319.241 has Departures 1 Arrivals 1 -> use SLOW 2
# Look ahead from 1 at time 319.663 has Departures 274 Arrivals 274 -> use SLOW 2
# Look ahead from 2 at time 320.502 has Departures 202 Arrivals 202 -> use SLOW 2
# Look ahead from 7 at time 322.034 has Departures 1 Arrivals 1 -> use SLOW 2
# Look ahead from 7 at time 322.441 has Departures 145 Arrivals 145 -> use SLOW 2
# Look ahead from 10 at time 323.890 has Departures 1 Arrivals 0 -> use SLOW 2
# Look ahead from 9 at time 324.550 has Departures 1 Arrivals 0 -> use SLOW 2
# Look ahead from 8 at time 324.714 has Departures 1 Arrivals 1 -> use SLOW 2
# Look ahead from 8 at time 327.801 has Departures 1 Arrivals 1 -> use SLOW 2
# Look ahead from 8 at time 328.858 has Departures 139 Arrivals 139 -> use SLOW 2
# Look ahead from 14 at time 335.158 has Departures 1 Arrivals 0 -> use SLOW 2
# Look ahead from 13 at time 335.857 has Departures 1 Arrivals 0 -> use SLOW 2
# Look ahead from 12 at time 335.997 has Departures 6 Arrivals 6 -> use SLOW 2
# Look ahead from 13 at time 337.641 has Departures 4 Arrivals 4 -> use SLOW 2
# Look ahead from 15 at time 339.372 has Departures 1 Arrivals 0 -> use SLOW 2
# Look ahead from 14 at time 339.578 has Departures 1 Arrivals 1 -> use SLOW 2
# Look ahead from 14 at time 339.803 has Departures 1 Arrivals 0 -> use SLOW 2
# Look ahead from 13 at time 339.970 has Departures 1 Arrivals 0 -> use SLOW 2
# Look ahead from 12 at time 340.266 has Departures 1 Arrivals 1 -> use SLOW 2
# Look ahead from 12 at time 341.227 has Departures 1 Arrivals 0 -> use SLOW 2
# Look ahead from 11 at time 341.398 has Departures 27 Arrivals 27 -> use SLOW 2
# Look ahead from 13 at time 345.413 has Departures 2 Arrivals 2 -> use SLOW 2
# Look ahead from 14 at time 346.105 has Departures 1 Arrivals 0 -> use SLOW 2
# Look ahead from 13 at time 346.172 has Departures 18 Arrivals 18 -> use SLOW 2
# Look ahead from 16 at time 347.340 has Departures 2 Arrivals 2 -> use SLOW 2
# Look ahead from 17 at time 349.634 has Departures 1 Arrivals 0 -> use SLOW 2
# Look ahead from 16 at time 350.721 has Departures 1 Arrivals 0 -> use SLOW 2
# Look ahead from 15 at time 351.013 has Departures 1 Arrivals 1 -> use SLOW 2
# Look ahead from 15 at time 351.584 has Departures 1 Arrivals 0 -> use SLOW 2
# Look ahead from 14 at time 352.360 has Departures 11 Arrivals 11 -> use SLOW 2
# Look ahead from 17 at time 357.304 has Departures 6 Arrivals 6 -> use SLOW 2
# Look ahead from 20 at time 358.212 has Departures 1 Arrivals 0 -> use SLOW 2
# Look ahead from 19 at time 358.246 has Departures 1 Arrivals 1 -> use SLOW 2
# Look ahead from 19 at time 358.806 has Departures 1 Arrivals 1 -> use SLOW 2
# Look ahead from 19 at time 359.590 has Departures 1 Arrivals 0 -> use SLOW 2
# Look ahead from 18 at time 359.924 has Departures 1 Arrivals 0 -> use SLOW 2
# Look ahead from 17 at time 361.120 has Departures 1 Arrivals 0 -> use SLOW 2
# Look ahead from 16 at time 361.426 has Departures 1 Arrivals 0 -> use SLOW 2
# Look ahead from 15 at time 361.527 has Departures 1 Arrivals 1 -> use SLOW 2
# Look ahead from 15 at time 362.399 has Departures 1 Arrivals 0 -> use SLOW 2
# Look ahead from 14 at time 362.539 has Departures 1 Arrivals 0 -> use SLOW 2
# Look ahead from 13 at time 362.789 has Departures 2 Arrivals 2 -> use SLOW 2
# Look ahead from 14 at time 365.464 has Departures 1 Arrivals 0 -> use SLOW 2
# Look ahead from 13 at time 365.742 has Departures 1 Arrivals 1 -> use SLOW 2
# Look ahead from 13 at time 366.150 has Departures 1 Arrivals 0 -> use SLOW 2
# Look ahead from 12 at time 366.343 has Departures 1 Arrivals 1 -> use SLOW 2
# Look ahead from 12 at time 368.257 has Departures 1 Arrivals 0 -> use SLOW 2
# Look ahead from 11 at time 368.646 has Departures 3 Arrivals 3 -> use SLOW 2
# Look ahead from 12 at time 370.080 has Departures 1 Arrivals 1 -> use SLOW 2
# Look ahead from 12 at time 371.444 has Departures 1 Arrivals 0 -> use SLOW 2
# Look ahead from 11 at time 371.953 has Departures 1 Arrivals 0 -> use SLOW 2
# Look ahead from 10 at time 373.207 has Departures 1 Arrivals 1 -> use SLOW 2
# Look ahead from 10 at time 373.984 has Departures 86 Arrivals 86 -> use SLOW 2
# Look ahead from 12 at time 375.640 has Departures 2 Arrivals 2 -> use SLOW 2
# Look ahead from 13 at time 377.535 has Departures 1 Arrivals 0 -> use SLOW 2
# Look ahead from 12 at time 378.261 has Departures 60 Arrivals 60 -> use SLOW 2
# Look ahead from 13 at time 380.819 has Departures 1 Arrivals 1 -> use SLOW 2
# Look ahead from 13 at time 381.194 has Departures 1 Arrivals 1 -> use SLOW 2
# Look ahead from 13 at time 382.381 has Departures 56 Arrivals 56 -> use SLOW 2
# Look ahead from 14 at time 383.753 has Departures 1 Arrivals 1 -> use SLOW 2
# Look ahead from 14 at time 384.672 has Departures 53 Arrivals 53 -> use SLOW 2
# Look ahead from 18 at time 388.817 has Departures 1 Arrivals 0 -> use SLOW 2
# Look ahead from 17 at time 389.230 has Departures 1 Arrivals 0 -> use SLOW 2
# Look ahead from 16 at time 389.564 has Departures 48 Arrivals 48 -> use SLOW 2
# Look ahead from 20 at time 390.722 has Departures 1 Arrivals 1 -> use SLOW 2
# Look ahead from 20 at time 391.311 has Departures 1 Arrivals 0 -> use SLOW 2
# Look ahead from 19 at time 392.013 has Departures 35 Arrivals 35 -> use SLOW 2
# Look ahead from 20 at time 393.766 has Departures 2 Arrivals 2 -> use SLOW 2
# Look ahead from 21 at time 395.072 has Departures 1 Arrivals 0 -> use SLOW 2
# Look ahead from 20 at time 395.081 has Departures 25 Arrivals 25 -> use SLOW 2
# Look ahead from 27 at time 401.789 has Departures 1 Arrivals 0 -> use SLOW 2
# Look ahead from 26 at time 401.796 has Departures 1 Arrivals 1 -> use SLOW 2
# Look ahead from 26 at time 402.330 has Departures 1 Arrivals 0 -> use SLOW 2
# Look ahead from 25 at time 402.605 has Departures 1 Arrivals 0 -> use SLOW 2
# Look ahead from 24 at time 404.200 has Departures 8 Arrivals 8 -> use SLOW 2
# Look ahead from 27 at time 406.397 has Departures 1 Arrivals 1 -> use SLOW 2
# Look ahead from 27 at time 407.315 has Departures 1 Arrivals 1 -> use SLOW 2
# Look ahead from 27 at time 408.022 has Departures 1 Arrivals 0 -> use SLOW 2
# Look ahead from 26 at time 408.188 has Departures 1 Arrivals 1 -> use SLOW 2
# Look ahead from 26 at time 409.170 has Departures 1 Arrivals 1 -> use SLOW 2
# Look ahead from 26 at time 412.372 has Departures 1 Arrivals 0 -> use SLOW 2
# Look ahead from 25 at time 413.873 has Departures 1 Arrivals 0 -> use SLOW 2
# Look ahead from 24 at time 414.009 has Departures 7 Arrivals 7 -> use SLOW 2
# Look ahead from 25 at time 415.524 has Departures 2 Arrivals 2 -> use SLOW 2
# Look ahead from 26 at time 417.259 has Departures 1 Arrivals 0 -> use SLOW 2
# Look ahead from 25 at time 417.416 has Departures 1 Arrivals 1 -> use SLOW 2
# Look ahead from 25 at time 418.811 has Departures 2 Arrivals 2 -> use SLOW 2
# Look ahead from 26 at time 421.679 has Departures 1 Arrivals 0 -> use SLOW 2
# Look ahead from 25 at time 421.945 has Departures 1 Arrivals 0 -> use SLOW 2
# Look ahead from 24 at time 422.093 has Departures 1 Arrivals 0 -> use SLOW 2
# Look ahead from 23 at time 422.679 has Departures 1 Arrivals 0 -> use SLOW 2
# Look ahead from 22 at time 423.083 has Departures 1 Arrivals 1 -> use SLOW 2
# Look ahead from 22 at time 423.941 has Departures 1 Arrivals 0 -> use SLOW 2
# Look ahead from 21 at time 424.438 has Departures 1 Arrivals 0 -> use SLOW 2
# Look ahead from 20 at time 424.816 has Departures 2 Arrivals 2 -> use SLOW 2
# Look ahead from 21 at time 425.846 has Departures 1 Arrivals 0 -> use SLOW 2
# Look ahead from 20 at time 425.944 has Departures 4 Arrivals 4 -> use SLOW 2
# Look ahead from 21 at time 427.372 has Departures 2 Arrivals 2 -> use SLOW 2
# Look ahead from 22 at time 427.616 has Departures 1 Arrivals 0 -> use SLOW 2
# Look ahead from 21 at time 427.703 has Departures 1 Arrivals 0 -> use SLOW 2
# Look ahead from 20 at time 428.850 has Departures 1 Arrivals 0 -> use SLOW 2
# Look ahead from 19 at time 429.386 has Departures 3 Arrivals 3 -> use SLOW 2
# Look ahead from 20 at time 429.818 has Departures 1 Arrivals 1 -> use SLOW 2
# Look ahead from 20 at time 430.159 has Departures 1 Arrivals 0 -> use SLOW 2
# Look ahead from 19 at time 430.185 has Departures 1 Arrivals 0 -> use SLOW 2
# Look ahead from 18 at time 430.338 has Departures 1 Arrivals 1 -> use SLOW 2
# Look ahead from 18 at time 430.395 has Departures 1 Arrivals 1 -> use SLOW 2
# Look ahead from 18 at time 431.497 has Departures 1 Arrivals 1 -> use SLOW 2
# Look ahead from 18 at time 432.003 has Departures 1 Arrivals 0 -> use SLOW 2
# Look ahead from 17 at time 432.258 has Departures 1 Arrivals 1 -> use SLOW 2
# Look ahead from 17 at time 433.692 has Departures 1 Arrivals 0 -> use SLOW 2
# Look ahead from 16 at time 433.982 has Departures 1 Arrivals 0 -> use SLOW 2
# Look ahead from 15 at time 434.785 has Departures 1 Arrivals 0 -> use SLOW 2
# Look ahead from 14 at time 435.462 has Departures 1 Arrivals 0 -> use SLOW 2
# Look ahead from 13 at time 436.345 has Departures 1 Arrivals 0 -> use SLOW 2
# Look ahead from 12 at time 437.090 has Departures 1 Arrivals 1 -> use SLOW 2
# Look ahead from 12 at time 437.574 has Departures 14 Arrivals 14 -> use SLOW 2
# Look ahead from 14 at time 439.130 has Departures 1 Arrivals 0 -> use SLOW 2
# Look ahead from 13 at time 439.799 has Departures 11 Arrivals 11 -> use SLOW 2
# Look ahead from 15 at time 441.071 has Departures 8 Arrivals 8 -> use SLOW 2
# Look ahead from 16 at time 443.200 has Departures 2 Arrivals 2 -> use SLOW 2
# Look ahead from 17 at time 443.933 has Departures 1 Arrivals 0 -> use SLOW 2
# Look ahead from 16 at time 443.946 has Departures 3 Arrivals 3 -> use SLOW 2
# Look ahead from 17 at time 446.986 has Departures 1 Arrivals 1 -> use SLOW 2
# Look ahead from 17 at time 449.334 has Departures 1 Arrivals 0 -> use SLOW 2
# Look ahead from 16 at time 449.723 has Departures 1 Arrivals 1 -> use SLOW 2
# Look ahead from 16 at time 451.211 has Departures 1 Arrivals 0 -> use SLOW 2
# Look ahead from 15 at time 451.937 has Departures 1 Arrivals 0 -> use SLOW 2
# Look ahead from 14 at time 452.265 has Departures 1 Arrivals 0 -> use SLOW 2
# Look ahead from 13 at time 452.499 has Departures 1 Arrivals 0 -> use SLOW 2
# Look ahead from 12 at time 452.643 has Departures 1 Arrivals 1 -> use SLOW 2
# Look ahead from 12 at time 453.097 has Departures 5 Arrivals 5 -> use SLOW 2
# Look ahead from 16 at time 458.648 has Departures 1 Arrivals 0 -> use SLOW 2
# Look ahead from 15 at time 458.710 has Departures 1 Arrivals 0 -> use SLOW 2
# Look ahead from 14 at time 458.989 has Departures 1 Arrivals 0 -> use SLOW 2
# Look ahead from 13 at time 459.395 has Departures 1 Arrivals 0 -> use SLOW 2
# Look ahead from 12 at time 460.599 has Departures 1 Arrivals 0 -> use SLOW 2
# Look ahead from 11 at time 461.020 has Departures 1 Arrivals 0 -> use SLOW 2
# Look ahead from 10 at time 461.841 has Departures 1 Arrivals 0 -> use SLOW 2
# Look ahead from 9 at time 461.872 has Departures 1 Arrivals 1 -> use SLOW 2
# Look ahead from 9 at time 462.914 has Departures 7 Arrivals 7 -> use SLOW 2
# Look ahead from 10 at time 465.473 has Departures 5 Arrivals 5 -> use SLOW 2
# Look ahead from 12 at time 467.775 has Departures 1 Arrivals 1 -> use SLOW 2
# Look ahead from 12 at time 469.191 has Departures 1 Arrivals 1 -> use SLOW 2
# Look ahead from 12 at time 470.600 has Departures 1 Arrivals 0 -> use SLOW 2
# Look ahead from 11 at time 472.542 has Departures 1 Arrivals 0 -> use SLOW 2
# Look ahead from 10 at time 472.759 has Departures 1 Arrivals 0 -> use SLOW 2
# Look ahead from 9 at time 473.507 has Departures 1 Arrivals 0 -> use SLOW 2
# Look ahead from 8 at time 473.529 has Departures 1 Arrivals 0 -> use SLOW 2
# Look ahead from 7 at time 473.676 has Departures 1 Arrivals 0 -> use SLOW 2
# Look ahead from 6 at time 473.768 has Departures 2 Arrivals 2 -> use SLOW 2
# Look ahead from 7 at time 474.116 has Departures 1 Arrivals 0 -> use SLOW 2
# Look ahead from 6 at time 474.609 has Departures 1 Arrivals 1 -> use SLOW 2
# Look ahead from 6 at time 475.901 has Departures 1 Arrivals 0 -> use SLOW 2
# Look ahead from 5 at time 476.515 has Departures 1 Arrivals 1 -> use SLOW 2
# Look ahead from 5 at time 477.926 has Departures 1 Arrivals 1 -> use SLOW 2
# Look ahead from 5 at time 481.572 has Departures 40 Arrivals 40 -> use SLOW 2
# Look ahead from 7 at time 482.822 has Departures 37 Arrivals 37 -> use SLOW 2
# Look ahead from 10 at time 485.276 has Departures 1 Arrivals 0 -> use SLOW 2
# Look ahead from 9 at time 485.897 has Departures 1 Arrivals 0 -> use SLOW 2
# Look ahead from 8 at time 486.296 has Departures 6 Arrivals 6 -> use SLOW 2
# Look ahead from 10 at time 489.615 has Departures 1 Arrivals 0 -> use SLOW 2
# Look ahead from 9 at time 490.817 has Departures 2 Arrivals 2 -> use SLOW 2
# Look ahead from 10 at time 491.953 has Departures 1 Arrivals 0 -> use SLOW 2
# Look ahead from 9 at time 492.562 has Departures 1 Arrivals 1 -> use SLOW 2
# Look ahead from 9 at time 493.081 has Departures 1 Arrivals 0 -> use SLOW 2
# Look ahead from 8 at time 493.160 has Departures 2 Arrivals 2 -> use SLOW 2
# Look ahead from 9 at time 493.619 has Departures 1 Arrivals 0 -> use SLOW 2
# Look ahead from 8 at time 494.354 has Departures 23 Arrivals 23 -> use SLOW 2
# Look ahead from 10 at time 496.233 has Departures 1 Arrivals 0 -> use SLOW 2
# Look ahead from 9 at time 497.317 has Departures 1 Arrivals 1 -> use SLOW 2
# Look ahead from 9 at time 499.973 has Departures 19 Arrivals 19 -> use SLOW 2
# Look ahead from 11 at time 501.413 has Departures 2 Arrivals 2 -> use SLOW 2
# Look ahead from 12 at time 501.926 has Departures 1 Arrivals 0 -> use SLOW 2
# Look ahead from 11 at time 502.360 has Departures 1 Arrivals 0 -> use SLOW 2
# Look ahead from 10 at time 502.569 has Departures 1 Arrivals 1 -> use SLOW 2
# Look ahead from 10 at time 503.685 has Departures 10 Arrivals 10 -> use SLOW 2
# Look ahead from 12 at time 506.377 has Departures 1 Arrivals 0 -> use SLOW 2
# Look ahead from 11 at time 506.693 has Departures 5 Arrivals 5 -> use SLOW 2
# Look ahead from 12 at time 508.358 has Departures 3 Arrivals 3 -> use SLOW 2
# Look ahead from 13 at time 510.042 has Departures 1 Arrivals 1 -> use SLOW 2
# Look ahead from 13 at time 511.952 has Departures 1 Arrivals 0 -> use SLOW 2
# Look ahead from 12 at time 512.404 has Departures 1 Arrivals 0 -> use SLOW 2
# Look ahead from 11 at time 512.876 has Departures 1 Arrivals 1 -> use SLOW 2
# Look ahead from 11 at time 516.853 has Departures 1 Arrivals 1 -> use SLOW 2
# Look ahead from 11 at time 517.922 has Departures 1 Arrivals 0 -> use SLOW 2
# Look ahead from 10 at time 518.305 has Departures 1 Arrivals 1 -> use SLOW 2
# Look ahead from 10 at time 520.575 has Departures 1 Arrivals 1 -> use SLOW 2
# Look ahead from 10 at time 521.576 has Departures 1 Arrivals 1 -> use SLOW 2
# Look ahead from 10 at time 523.095 has Departures 1 Arrivals 0 -> use SLOW 2
# Look ahead from 9 at time 523.603 has Departures 1 Arrivals 0 -> use SLOW 2
# Look ahead from 8 at time 524.186 has Departures 1 Arrivals 1 -> use SLOW 2
# Look ahead from 8 at time 525.337 has Departures 1 Arrivals 1 -> use SLOW 2
# Look ahead from 8 at time 526.808 has Departures 1 Arrivals 0 -> use SLOW 2
# Look ahead from 7 at time 527.167 has Departures 1 Arrivals 0 -> use SLOW 2
# Look ahead from 6 at time 527.239 has Departures 1 Arrivals 0 -> use SLOW 2
# Look ahead from 5 at time 527.574 has Departures 1 Arrivals 1 -> use SLOW 2
# Look ahead from 5 at time 529.003 has Departures 1 Arrivals 0 -> use SLOW 2
# Look ahead from 4 at time 530.210 has Departures 2 Arrivals 2 -> use SLOW 2
# Look ahead from 5 at time 531.374 has Departures 1 Arrivals 0 -> use SLOW 2
# Look ahead from 4 at time 531.556 has Departures 1 Arrivals 1 -> use SLOW 2
# Look ahead from 4 at time 532.127 has Departures 1 Arrivals 0 -> use SLOW 2
# Look ahead from 3 at time 532.129 has Departures 1 Arrivals 1 -> use SLOW 2
# Look ahead from 3 at time 533.237 has Departures 1 Arrivals 0 -> use SLOW 2
# Look ahead from 2 at time 533.544 has Departures 1 Arrivals 1 -> use SLOW 2
# Look ahead from 2 at time 533.969 has Departures 65 Arrivals 65 -> use SLOW 2
# Look ahead from 6 at time 538.182 has Departures 1 Arrivals 1 -> use SLOW 2
# Look ahead from 6 at time 540.439 has Departures 1 Arrivals 1 -> use SLOW 2
# Look ahead from 6 at time 542.036 has Departures 3 Arrivals 3 -> use SLOW 2
# Look ahead from 8 at time 543.329 has Departures 1 Arrivals 0 -> use SLOW 2
# Look ahead from 7 at time 543.616 has Departures 1 Arrivals 0 -> use SLOW 2
# Look ahead from 6 at time 544.797 has Departures 1 Arrivals 0 -> use SLOW 2
# Look ahead from 5 at time 545.299 has Departures 1 Arrivals 0 -> use SLOW 2
# Look ahead from 4 at time 545.338 has Departures 1 Arrivals 1 -> use SLOW 2
# Look ahead from 4 at time 546.237 has Departures 52 Arrivals 52 -> use SLOW 2
# Look ahead from 5 at time 546.655 has Departures 4 Arrivals 4 -> use SLOW 2
# Look ahead from 6 at time 548.100 has Departures 1 Arrivals 1 -> use SLOW 2
# Look ahead from 6 at time 548.443 has Departures 1 Arrivals 1 -> use SLOW 2
# Look ahead from 6 at time 548.887 has Departures 1 Arrivals 0 -> use SLOW 2
# Look ahead from 5 at time 549.235 has Departures 46 Arrivals 46 -> use SLOW 2
# Look ahead from 6 at time 551.349 has Departures 37 Arrivals 37 -> use SLOW 2
# Look ahead from 8 at time 554.904 has Departures 1 Arrivals 1 -> use SLOW 2
# Look ahead from 8 at time 555.590 has Departures 1 Arrivals 1 -> use SLOW 2
# Look ahead from 8 at time 556.185 has Departures 32 Arrivals 32 -> use SLOW 2
# Look ahead from 11 at time 557.239 has Departures 25 Arrivals 25 -> use SLOW 2
# Look ahead from 13 at time 558.185 has Departures 2 Arrivals 2 -> use SLOW 2
# Look ahead from 14 at time 558.721 has Departures 1 Arrivals 0 -> use SLOW 2
# Look ahead from 13 at time 558.829 has Departures 1 Arrivals 1 -> use SLOW 2
# Look ahead from 13 at time 560.163 has Departures 18 Arrivals 18 -> use SLOW 2
# Look ahead from 20 at time 562.836 has Departures 1 Arrivals 1 -> use SLOW 2
# Look ahead from 20 at time 564.136 has Departures 1 Arrivals 0 -> use SLOW 2
# Look ahead from 19 at time 564.725 has Departures 2 Arrivals 2 -> use SLOW 2
# Look ahead from 20 at time 565.806 has Departures 1 Arrivals 0 -> use SLOW 2
# Look ahead from 19 at time 566.505 has Departures 1 Arrivals 1 -> use SLOW 2
# Look ahead from 19 at time 566.940 has Departures 1 Arrivals 1 -> use SLOW 2
# Look ahead from 19 at time 568.032 has Departures 1 Arrivals 0 -> use SLOW 2
# Look ahead from 18 at time 568.796 has Departures 1 Arrivals 0 -> use SLOW 2
# Look ahead from 17 at time 569.229 has Departures 1 Arrivals 1 -> use SLOW 2
# Look ahead from 17 at time 571.510 has Departures 3 Arrivals 3 -> use SLOW 2
# Look ahead from 18 at time 572.673 has Departures 1 Arrivals 1 -> use SLOW 2
# Look ahead from 18 at time 573.047 has Departures 1 Arrivals 0 -> use SLOW 2
# Look ahead from 17 at time 573.400 has Departures 1 Arrivals 0 -> use SLOW 2
# Look ahead from 16 at time 574.279 has Departures 1 Arrivals 1 -> use SLOW 2
# Look ahead from 16 at time 574.805 has Departures 1 Arrivals 0 -> use SLOW 2
# Look ahead from 15 at time 575.108 has Departures 1 Arrivals 0 -> use SLOW 2
# Look ahead from 14 at time 575.218 has Departures 1 Arrivals 0 -> use SLOW 2
# Look ahead from 13 at time 575.525 has Departures 1 Arrivals 0 -> use SLOW 2
# Look ahead from 12 at time 576.655 has Departures 1 Arrivals 1 -> use SLOW 2
# Look ahead from 12 at time 577.896 has Departures 1 Arrivals 0 -> use SLOW 2
# Look ahead from 11 at time 578.008 has Departures 1 Arrivals 0 -> use SLOW 2
# Look ahead from 10 at time 578.178 has Departures 1 Arrivals 0 -> use SLOW 2
# Look ahead from 9 at time 578.405 has Departures 1 Arrivals 1 -> use SLOW 2
# Look ahead from 9 at time 578.545 has Departures 2 Arrivals 2 -> use SLOW 2
# Look ahead from 10 at time 579.846 has Departures 1 Arrivals 0 -> use SLOW 2
# Look ahead from 9 at time 580.647 has Departures 1 Arrivals 0 -> use SLOW 2
# Look ahead from 8 at time 581.150 has Departures 1 Arrivals 0 -> use SLOW 2
# Look ahead from 7 at time 582.339 has Departures 1 Arrivals 0 -> use SLOW 2
# Look ahead from 6 at time 582.824 has Departures 1 Arrivals 1 -> use SLOW 2
# Look ahead from 6 at time 583.426 has Departures 3 Arrivals 3 -> use SLOW 2
# Look ahead from 7 at time 584.046 has Departures 1 Arrivals 1 -> use SLOW 2
# Look ahead from 7 at time 586.768 has Departures 1 Arrivals 0 -> use SLOW 2
# Look ahead from 6 at time 586.919 has Departures 1 Arrivals 1 -> use SLOW 2
# Look ahead from 6 at time 587.698 has Departures 2 Arrivals 2 -> use SLOW 2
# Look ahead from 7 at time 589.657 has Departures 1 Arrivals 0 -> use SLOW 2
# Look ahead from 6 at time 589.821 has Departures 1 Arrivals 0 -> use SLOW 2
# Look ahead from 5 at time 589.861 has Departures 1 Arrivals 0 -> use SLOW 2
# Look ahead from 4 at time 591.421 has Departures 1 Arrivals 1 -> use SLOW 2
# Look ahead from 4 at time 593.239 has Departures 1 Arrivals 1 -> use SLOW 2
# Look ahead from 4 at time 593.829 has Departures 1 Arrivals 0 -> use SLOW 2
# Look ahead from 3 at time 594.957 has Departures 1 Arrivals 0 -> use SLOW 2
# Look ahead from 2 at time 595.087 has Departures 4 Arrivals 4 -> use SLOW 2
# Look ahead from 5 at time 597.965 has Departures 1 Arrivals 0 -> use SLOW 2
# Look ahead from 4 at time 598.149 has Departures 1 Arrivals 0 -> use SLOW 2
# Look ahead from 3 at time 598.351 has Departures 1 Arrivals 0 -> use SLOW 2
# Look ahead from 2 at time 599.432 has Departures 1 Arrivals 0 -> use SLOW 2
# Look ahead from 1 at time 599.711 has Departures 1 Arrivals 0 -> use SLOW 2
# Look ahead from 1 at time 600.721 has Departures 4 Arrivals 4 -> use SLOW 1
# Look ahead from 2 at time 601.884 has Departures 1 Arrivals 1 -> use SLOW 2
# Look ahead from 2 at time 602.317 has Departures 1 Arrivals 1 -> use SLOW 2
# Look ahead from 2 at time 603.899 has Departures 1 Arrivals 0 -> use SLOW 2
# Look ahead from 1 at time 604.873 has Departures 1 Arrivals 1 -> use SLOW 2
# Look ahead from 1 at time 606.717 has Departures 8790 Arrivals 9437 -> use FAST 2
# ...
# Look ahead from 2 at time 9793.787 has Departures 1 Arrivals 0 -> use SLOW 2
# Look ahead from 1 at time 9793.892 has Departures 1 Arrivals 1 -> use SLOW 2
# Look ahead from 1 at time 9794.248 has Departures 1 Arrivals 0 -> use SLOW 2
# Look ahead from 1 at time 9795.846 has Departures 1 Arrivals 0 -> use SLOW 1
# Look ahead from 1 at time 9796.121 has Departures 16 Arrivals 16 -> use SLOW 1
# Look ahead from 3 at time 9796.880 has Departures 9 Arrivals 9 -> use SLOW 2
# Look ahead from 4 at time 9799.434 has Departures 6 Arrivals 6 -> use SLOW 2
# Look ahead from 7 at time 9802.632 has Departures 1 Arrivals 1 -> use SLOW 2
# Look ahead from 7 at time 9803.239 has Departures 1 Arrivals 0 -> use SLOW 2
# Look ahead from 6 at time 9803.739 has Departures 1 Arrivals 0 -> use SLOW 2
# Look ahead from 5 at time 9804.102 has Departures 1 Arrivals 1 -> use SLOW 2
# Look ahead from 5 at time 9805.302 has Departures 1 Arrivals 0 -> use SLOW 2
# Look ahead from 4 at time 9805.994 has Departures 1 Arrivals 1 -> use SLOW 2
# Look ahead from 4 at time 9806.427 has Departures 1 Arrivals 0 -> use SLOW 2
# Look ahead from 3 at time 9806.695 has Departures 4 Arrivals 4 -> use SLOW 2
# Look ahead from 5 at time 9807.883 has Departures 1 Arrivals 0 -> use SLOW 2
# Look ahead from 4 at time 9808.327 has Departures 1 Arrivals 1 -> use SLOW 2
# Look ahead from 4 at time 9809.991 has Departures 1 Arrivals 0 -> use SLOW 2
# Look ahead from 3 at time 9810.137 has Departures 1 Arrivals 0 -> use SLOW 2
# Look ahead from 2 at time 9811.082 has Departures 1 Arrivals 0 -> use SLOW 2
# Look ahead from 1 at time 9811.670 has Departures 1 Arrivals 1 -> use SLOW 2
# Look ahead from 1 at time 9812.724 has Departures 1 Arrivals 1 -> use SLOW 2
# Look ahead from 1 at time 9812.861 has Departures 3 Arrivals 3 -> use SLOW 2
# Look ahead from 3 at time 9813.821 has Departures 1 Arrivals 0 -> use SLOW 2
# Look ahead from 2 at time 9814.128 has Departures 1 Arrivals 0 -> use SLOW 2
# Look ahead from 1 at time 9815.905 has Departures 157 Arrivals 179 -> use FAST 2
# Look ahead from 1 at time 9817.168 has Departures 1 Arrivals 1 -> use SLOW 1
# Look ahead from 1 at time 9817.546 has Departures 10 Arrivals 10 -> use SLOW 2
# Look ahead from 7 at time 9819.703 has Departures 1 Arrivals 1 -> use SLOW 2
# Look ahead from 7 at time 9821.412 has Departures 1 Arrivals 0 -> use SLOW 2
# Look ahead from 6 at time 9821.743 has Departures 1 Arrivals 0 -> use SLOW 2
# Look ahead from 5 at time 9821.833 has Departures 1 Arrivals 0 -> use SLOW 2
# Look ahead from 4 at time 9821.990 has Departures 1 Arrivals 0 -> use SLOW 2
# Look ahead from 3 at time 9822.899 has Departures 1 Arrivals 0 -> use SLOW 2
# Look ahead from 2 at time 9823.009 has Departures 2 Arrivals 2 -> use SLOW 2
# Look ahead from 3 at time 9824.814 has Departures 1 Arrivals 0 -> use SLOW 2
# Look ahead from 2 at time 9824.942 has Departures 1 Arrivals 0 -> use SLOW 2
# Look ahead from 1 at time 9826.078 has Departures 1 Arrivals 1 -> use SLOW 2
# Look ahead from 1 at time 9826.254 has Departures 1 Arrivals 1 -> use SLOW 2
# Look ahead from 1 at time 9826.791 has Departures 1 Arrivals 0 -> use SLOW 2
# Look ahead from 1 at time 9827.561 has Departures 143 Arrivals 164 -> use FAST 1
# Look ahead from 1 at time 9827.962 has Departures 18 Arrivals 18 -> use SLOW 1
# Look ahead from 6 at time 9830.655 has Departures 1 Arrivals 0 -> use SLOW 2
# Look ahead from 5 at time 9833.385 has Departures 1 Arrivals 1 -> use SLOW 2
# Look ahead from 5 at time 9834.822 has Departures 1 Arrivals 0 -> use SLOW 2
# Look ahead from 4 at time 9834.899 has Departures 1 Arrivals 0 -> use SLOW 2
# Look ahead from 3 at time 9835.051 has Departures 11 Arrivals 11 -> use SLOW 2
# Look ahead from 4 at time 9836.770 has Departures 9 Arrivals 9 -> use SLOW 2
# Look ahead from 7 at time 9839.197 has Departures 1 Arrivals 0 -> use SLOW 2
# Look ahead from 6 at time 9839.868 has Departures 1 Arrivals 0 -> use SLOW 2
# Look ahead from 5 at time 9839.882 has Departures 3 Arrivals 3 -> use SLOW 2
# Look ahead from 7 at time 9841.670 has Departures 1 Arrivals 0 -> use SLOW 2
# Look ahead from 6 at time 9841.724 has Departures 1 Arrivals 0 -> use SLOW 2
# Look ahead from 5 at time 9841.780 has Departures 2 Arrivals 2 -> use SLOW 2
# Look ahead from 6 at time 9844.491 has Departures 1 Arrivals 0 -> use SLOW 2
# Look ahead from 5 at time 9844.779 has Departures 1 Arrivals 0 -> use SLOW 2
# Look ahead from 4 at time 9845.290 has Departures 1 Arrivals 0 -> use SLOW 2
# Look ahead from 3 at time 9845.533 has Departures 1 Arrivals 0 -> use SLOW 2
# Look ahead from 2 at time 9848.344 has Departures 1 Arrivals 0 -> use SLOW 2
# Look ahead from 1 at time 9848.659 has Departures 125 Arrivals 145 -> use FAST 2
# Look ahead from 1 at time 9848.900 has Departures 1 Arrivals 0 -> use SLOW 1
# Look ahead from 1 at time 9850.450 has Departures 1 Arrivals 1 -> use SLOW 1
# Look ahead from 1 at time 9852.012 has Departures 123 Arrivals 142 -> use FAST 2
# Look ahead from 1 at time 9852.962 has Departures 2 Arrivals 2 -> use SLOW 1
# Look ahead from 2 at time 9856.468 has Departures 1 Arrivals 0 -> use SLOW 2
# Look ahead from 1 at time 9856.583 has Departures 1 Arrivals 0 -> use SLOW 2
# Look ahead from 1 at time 9857.584 has Departures 1 Arrivals 0 -> use SLOW 1
# Look ahead from 1 at time 9858.655 has Departures 118 Arrivals 137 -> use FAST 1
# Look ahead from 1 at time 9859.047 has Departures 118 Arrivals 136 -> use FAST 1
# Look ahead from 1 at time 9859.244 has Departures 117 Arrivals 135 -> use FAST 1
# Look ahead from 1 at time 9859.411 has Departures 1 Arrivals 0 -> use SLOW 1
# Look ahead from 1 at time 9860.402 has Departures 115 Arrivals 133 -> use FAST 1
# Look ahead from 1 at time 9861.262 has Departures 116 Arrivals 132 -> use FAST 1
# Look ahead from 1 at time 9861.387 has Departures 1 Arrivals 0 -> use SLOW 1
# Look ahead from 1 at time 9862.075 has Departures 1 Arrivals 0 -> use SLOW 1
# Look ahead from 1 at time 9862.956 has Departures 113 Arrivals 129 -> use FAST 1
# Look ahead from 1 at time 9863.179 has Departures 1 Arrivals 0 -> use SLOW 1
# Look ahead from 1 at time 9863.870 has Departures 1 Arrivals 1 -> use SLOW 1
# Look ahead from 1 at time 9864.825 has Departures 2 Arrivals 2 -> use SLOW 2
# Look ahead from 2 at time 9869.701 has Departures 1 Arrivals 0 -> use SLOW 2
# Look ahead from 1 at time 9869.857 has Departures 5 Arrivals 5 -> use SLOW 2
# Look ahead from 5 at time 9872.823 has Departures 1 Arrivals 0 -> use SLOW 2
# Look ahead from 4 at time 9873.305 has Departures 1 Arrivals 0 -> use SLOW 2
# Look ahead from 3 at time 9874.474 has Departures 1 Arrivals 0 -> use SLOW 2
# Look ahead from 2 at time 9876.111 has Departures 1 Arrivals 0 -> use SLOW 2
# Look ahead from 1 at time 9877.503 has Departures 1 Arrivals 1 -> use SLOW 2
# Look ahead from 1 at time 9879.042 has Departures 1 Arrivals 1 -> use SLOW 2
# Look ahead from 1 at time 9881.168 has Departures 3 Arrivals 3 -> use SLOW 2
# Look ahead from 3 at time 9886.058 has Departures 1 Arrivals 0 -> use SLOW 2
# Look ahead from 2 at time 9886.246 has Departures 1 Arrivals 0 -> use SLOW 2
# Look ahead from 1 at time 9886.912 has Departures 1 Arrivals 0 -> use SLOW 2
# Look ahead from 1 at time 9888.303 has Departures 102 Arrivals 113 -> use FAST 1
# Look ahead from 1 at time 9888.418 has Departures 4 Arrivals 4 -> use SLOW 1
# Look ahead from 2 at time 9889.864 has Departures 2 Arrivals 2 -> use SLOW 2
# Look ahead from 3 at time 9891.143 has Departures 1 Arrivals 0 -> use SLOW 2
# Look ahead from 2 at time 9891.945 has Departures 1 Arrivals 0 -> use SLOW 2
# Look ahead from 1 at time 9892.321 has Departures 72 Arrivals 72 -> use SLOW 2
# Look ahead from 2 at time 9895.332 has Departures 70 Arrivals 70 -> use SLOW 2
# Look ahead from 4 at time 9896.007 has Departures 1 Arrivals 0 -> use SLOW 2
# Look ahead from 3 at time 9896.109 has Departures 67 Arrivals 67 -> use SLOW 2
# Look ahead from 4 at time 9896.890 has Departures 5 Arrivals 5 -> use SLOW 2
# Look ahead from 5 at time 9898.217 has Departures 1 Arrivals 1 -> use SLOW 2
# Look ahead from 5 at time 9901.402 has Departures 1 Arrivals 1 -> use SLOW 2
# Look ahead from 5 at time 9901.612 has Departures 1 Arrivals 1 -> use SLOW 2
# Look ahead from 5 at time 9902.672 has Departures 1 Arrivals 0 -> use SLOW 2
# Look ahead from 4 at time 9903.078 has Departures 1 Arrivals 1 -> use SLOW 2
# Look ahead from 4 at time 9903.754 has Departures 59 Arrivals 59 -> use SLOW 2
# Look ahead from 6 at time 9906.406 has Departures 4 Arrivals 4 -> use SLOW 2
# Look ahead from 8 at time 9908.006 has Departures 1 Arrivals 1 -> use SLOW 2
# Look ahead from 8 at time 9908.530 has Departures 1 Arrivals 0 -> use SLOW 2
# Look ahead from 7 at time 9910.047 has Departures 1 Arrivals 0 -> use SLOW 2
# Look ahead from 6 at time 9911.586 has Departures 1 Arrivals 1 -> use SLOW 2
# Look ahead from 6 at time 9912.380 has Departures 1 Arrivals 0 -> use SLOW 2
# Look ahead from 5 at time 9912.608 has Departures 50 Arrivals 50 -> use SLOW 2
# Look ahead from 6 at time 9916.895 has Departures 48 Arrivals 48 -> use SLOW 2
# Look ahead from 9 at time 9918.925 has Departures 1 Arrivals 1 -> use SLOW 2
# Look ahead from 9 at time 9920.785 has Departures 2 Arrivals 2 -> use SLOW 2
# Look ahead from 10 at time 9921.665 has Departures 1 Arrivals 0 -> use SLOW 2
# Look ahead from 9 at time 9921.789 has Departures 7 Arrivals 7 -> use SLOW 2
# Look ahead from 13 at time 9924.808 has Departures 1 Arrivals 1 -> use SLOW 2
# Look ahead from 13 at time 9926.703 has Departures 1 Arrivals 1 -> use SLOW 2
# Look ahead from 13 at time 9928.281 has Departures 1 Arrivals 0 -> use SLOW 2
# Look ahead from 12 at time 9929.454 has Departures 1 Arrivals 0 -> use SLOW 2
# Look ahead from 11 at time 9930.108 has Departures 1 Arrivals 0 -> use SLOW 2
# Look ahead from 10 at time 9930.282 has Departures 1 Arrivals 0 -> use SLOW 2
# Look ahead from 9 at time 9930.819 has Departures 1 Arrivals 1 -> use SLOW 2
# Look ahead from 9 at time 9932.794 has Departures 1 Arrivals 0 -> use SLOW 2
# Look ahead from 8 at time 9933.215 has Departures 1 Arrivals 0 -> use SLOW 2
# Look ahead from 7 at time 9933.360 has Departures 31 Arrivals 31 -> use SLOW 2
# Look ahead from 8 at time 9934.432 has Departures 29 Arrivals 29 -> use SLOW 2
# Look ahead from 11 at time 9936.258 has Departures 7 Arrivals 7 -> use SLOW 2
# Look ahead from 14 at time 9938.700 has Departures 1 Arrivals 0 -> use SLOW 2
# Look ahead from 13 at time 9939.129 has Departures 1 Arrivals 0 -> use SLOW 2
# Look ahead from 12 at time 9940.109 has Departures 1 Arrivals 1 -> use SLOW 2
# Look ahead from 12 at time 9941.265 has Departures 2 Arrivals 2 -> use SLOW 2
# Look ahead from 13 at time 9942.337 has Departures 1 Arrivals 0 -> use SLOW 2
# Look ahead from 12 at time 9942.527 has Departures 1 Arrivals 0 -> use SLOW 2
# Look ahead from 11 at time 9943.228 has Departures 1 Arrivals 1 -> use SLOW 2
# Look ahead from 11 at time 9943.766 has Departures 1 Arrivals 1 -> use SLOW 2
# Look ahead from 11 at time 9944.679 has Departures 1 Arrivals 0 -> use SLOW 2
# Look ahead from 10 at time 9945.031 has Departures 15 Arrivals 15 -> use SLOW 2
# Look ahead from 13 at time 9945.921 has Departures 1 Arrivals 1 -> use SLOW 2
# Look ahead from 13 at time 9946.109 has Departures 10 Arrivals 10 -> use SLOW 2
# Look ahead from 15 at time 9946.834 has Departures 7 Arrivals 7 -> use SLOW 2
# Look ahead from 17 at time 9947.603 has Departures 1 Arrivals 1 -> use SLOW 2
# Look ahead from 17 at time 9949.011 has Departures 1 Arrivals 0 -> use SLOW 2
# Look ahead from 16 at time 9949.532 has Departures 3 Arrivals 3 -> use SLOW 2
# Look ahead from 18 at time 9950.777 has Departures 1 Arrivals 0 -> use SLOW 2
# Look ahead from 17 at time 9951.264 has Departures 1 Arrivals 0 -> use SLOW 2
# Look ahead from 16 at time 9953.473 has Departures 1 Arrivals 0 -> use SLOW 2
# Look ahead from 15 at time 9954.002 has Departures 1 Arrivals 0 -> use SLOW 2
# Look ahead from 14 at time 9955.738 has Departures 1 Arrivals 0 -> use SLOW 2
# Look ahead from 13 at time 9956.024 has Departures 1 Arrivals 0 -> use SLOW 2
# Look ahead from 12 at time 9957.108 has Departures 1 Arrivals 0 -> use SLOW 2
# Look ahead from 11 at time 9958.412 has Departures 1 Arrivals 0 -> use SLOW 2
# Look ahead from 10 at time 9958.472 has Departures 1 Arrivals 0 -> use SLOW 2
# Look ahead from 9 at time 9958.480 has Departures 1 Arrivals 1 -> use SLOW 2
# Look ahead from 9 at time 9958.816 has Departures 1 Arrivals 0 -> use SLOW 2
# Look ahead from 8 at time 9958.917 has Departures 1 Arrivals 0 -> use SLOW 2
# Look ahead from 7 at time 9959.127 has Departures 2 Arrivals 2 -> use SLOW 2
# Look ahead from 8 at time 9959.437 has Departures 1 Arrivals 0 -> use SLOW 2
# Look ahead from 7 at time 9959.478 has Departures 1 Arrivals 0 -> use SLOW 2
# Look ahead from 6 at time 9960.063 has Departures 1 Arrivals 0 -> use SLOW 2
# Look ahead from 5 at time 9960.984 has Departures 1 Arrivals 1 -> use SLOW 2
# Look ahead from 5 at time 9961.157 has Departures 1 Arrivals 0 -> use SLOW 2
# Look ahead from 4 at time 9962.383 has Departures 1 Arrivals 0 -> use SLOW 2
# Look ahead from 3 at time 9962.506 has Departures 1 Arrivals 0 -> use SLOW 2
# Look ahead from 2 at time 9962.568 has Departures 1 Arrivals 0 -> use SLOW 2
# Look ahead from 1 at time 9962.726 has Departures 1 Arrivals 0 -> use SLOW 2
# Look ahead from 1 at time 9963.330 has Departures 26 Arrivals 35 -> use FAST 1
# Look ahead from 1 at time 9964.246 has Departures 1 Arrivals 0 -> use SLOW 1
# Look ahead from 1 at time 9966.347 has Departures 30 Arrivals 33 -> use FAST 1
# Look ahead from 1 at time 9968.033 has Departures 4 Arrivals 4 -> use SLOW 1
# Look ahead from 2 at time 9969.380 has Departures 2 Arrivals 2 -> use SLOW 2
# Look ahead from 3 at time 9970.468 has Departures 1 Arrivals 0 -> use SLOW 2
# Look ahead from 2 at time 9970.698 has Departures 1 Arrivals 0 -> use SLOW 2
# Look ahead from 1 at time 9971.855 has Departures 1 Arrivals 0 -> use SLOW 2
# Look ahead from 1 at time 9972.215 has Departures 1 Arrivals 1 -> use SLOW 1
# Look ahead from 1 at time 9972.741 has Departures 3 Arrivals 3 -> use SLOW 2
# Look ahead from 2 at time 9973.838 has Departures 1 Arrivals 1 -> use SLOW 2
# Look ahead from 2 at time 9973.965 has Departures 1 Arrivals 0 -> use SLOW 2
# Look ahead from 1 at time 9974.704 has Departures 21 Arrivals 23 -> use FAST 2
# Look ahead from 1 at time 9974.788 has Departures 2 Arrivals 2 -> use SLOW 1
# Look ahead from 2 at time 9977.197 has Departures 1 Arrivals 0 -> use SLOW 2
# Look ahead from 1 at time 9979.724 has Departures 15 Arrivals 15 -> use SLOW 2
# Look ahead from 3 at time 9981.327 has Departures 1 Arrivals 0 -> use SLOW 2
# Look ahead from 2 at time 9982.098 has Departures 12 Arrivals 12 -> use SLOW 2
# Look ahead from 5 at time 9985.617 has Departures 1 Arrivals 0 -> use SLOW 2
# Look ahead from 4 at time 9985.797 has Departures 1 Arrivals 1 -> use SLOW 2
# Look ahead from 4 at time 9986.820 has Departures 4 Arrivals 4 -> use SLOW 2
# Look ahead from 5 at time 9988.118 has Departures 2 Arrivals 2 -> use SLOW 2
# Look ahead from 6 at time 9989.484 has Departures 1 Arrivals 0 -> use SLOW 2
# Look ahead from 5 at time 9989.613 has Departures 1 Arrivals 0 -> use SLOW 2
# Look ahead from 4 at time 9989.948 has Departures 1 Arrivals 0 -> use SLOW 2
# Look ahead from 3 at time 9990.538 has Departures 1 Arrivals 1 -> use SLOW 2
# Look ahead from 3 at time 9990.977 has Departures 1 Arrivals 1 -> use SLOW 2
# Look ahead from 3 at time 9992.067 has Departures 1 Arrivals 1 -> use SLOW 2
# Look ahead from 3 at time 9992.389 has Departures 1 Arrivals 0 -> use SLOW 2
# Look ahead from 2 at time 9993.052 has Departures 1 Arrivals 0 -> use SLOW 2
# Look ahead from 1 at time 9993.164 has Departures 3 Arrivals 3 -> use SLOW 2
# Look ahead from 3 at time 9995.242 has Departures 1 Arrivals 0 -> use SLOW 2
# Look ahead from 2 at time 9995.601 has Departures 1 Arrivals 0 -> use SLOW 2
# Look ahead from 1 at time 9995.927 has Departures 1 Arrivals 1 -> use SLOW 2
# Look ahead from 1 at time 9997.519 has Departures 1 Arrivals 0 -> use SLOW 2
# Look ahead from 1 at time 9998.268 has Departures 0 Arrivals 0 -> use FAST 1
# Look ahead from 1 at time 999999.000 has Departures 0 Arrivals 0 -> use FAST 1
# Use surge 0.05

# %%
len(N1)
# Out:
# 19419

# %%
T2, N2, _, use_surge = MM1WithOneThreshold(arrivals, surge_threshold, c, Tmax)

start_index2 = int(len(T2)*start_prop)
end_index2 = int(len(T2)*end_prop)
figure(figsize=(15,6))
plot(T2[start_index2:end_index2], N2[start_index2:end_index2])
xlabel('Time')
ylabel('Number of clients')
title('Number of clients in the M/M/C queue %.2f/%.2f/%d, with threshold %d'
      % (lambd, mu1, c, surge_threshold))
print("Use surge %.2f" % (use_surge))
# Out:
# Use surge 0.07

# %%
figure(figsize=(15,7))
plot(T1[start_index1:end_index1], N1[start_index1:end_index1], label="Q_0")
plot(T2[start_index2:end_index2], N2[start_index2:end_index2], label="after applying threshold=80")
plot(T3[start_index3:end_index3], N3[start_index3:end_index3], label="after applying no job left behind")
xlabel('Time')
ylabel('Number of clients')
legend()
title('Number of clients in the M/M/C queue %.2f/%.2f/%d, with different heuristics'
      % (lambd, mu1, c))
# Out:
# Text(0.5,1,'Number of clients in the M/M/C queue 1.00/0.95/1, with different heuristics')

# %%
'''##### SURGE count and proportion #####
            if T[-1] >= 1000 and T[-1] <= 9000:
                if in_surge == 0 and S == 0: # first time, mark t_temp
                    start_measuring_surge = T[-2]
                t_delta = T[-1] - popped_customer.enter_service_time
                S = S + (t_delta * N[-2])
                if popped_customer.fast:
                    in_surge = in_surge + t_delta
            if T[-1] > 9000:
                if end_measuring_surge == 0:
                    end_measuring_surge = T[-1]'''
# Out:
# '##### SURGE count and proportion #####\n            if T[-1] >= 1000 and T[-1] <= 9000:\n                if in_surge == 0 and S == 0: # first time, mark t_temp\n                    start_measuring_surge = T[-2]\n                t_delta = T[-1] - popped_customer.enter_service_time\n                S = S + (t_delta * N[-2])\n                if popped_customer.fast:\n                    in_surge = in_surge + t_delta\n            if T[-1] > 9000:\n                if end_measuring_surge == 0:\n                    end_measuring_surge = T[-1]'
